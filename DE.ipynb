# %%
import pandas as pd
import numpy as np
import math
import sko
import keras
from math import sqrt
import os
import csv
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate
import sys
sys.path.append(r"D:\Anaconda\Lib\site-packages")
from sko.DE import DE

from keras import optimizers
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import numpy.linalg as la
import time
import random
from sko.DE import DE
tensorflow.random.set_seed(2)

exchanges = ["binance", "coinbase", "huobi", "kraken", "kucoin"]

class Population:
    def __init__(self, min_range, max_range, dim, factor, rounds, size, object_func, CR=0.75):
        self.min_range = min_range
        self.max_range = max_range
        self.dimension = dim
        self.factor = factor
        self.rounds = rounds
        self.size = size
        self.cur_round = 1
        self.CR = CR
        self.get_object_function_value = object_func
        # 初始化种群
        self.individuality = [np.array([random.uniform(self.min_range, self.max_range) for s in range(self.dimension)]) for tmp in range(size)]
        self.object_function_values = [self.get_object_function_value(v) for v in self.individuality]
        self.mutant = None

    def mutate(self):
        self.mutant = []
        for i in range(self.size):
            r0, r1, r2 = 0, 0, 0
            while r0 == r1 or r1 == r2 or r0 == r2 or r0 == i:
                r0 = random.randint(0, self.size-1)
                r1 = random.randint(0, self.size-1)
                r2 = random.randint(0, self.size-1)
            tmp = self.individuality[r0] + (self.individuality[r1] - self.individuality[r2]) * self.factor
            for t in range(self.dimension):
                if tmp[t] > self.max_range or tmp[t] < self.min_range:
                    tmp[t] = random.uniform(self.min_range, self.max_range)
            self.mutant.append(tmp)

    def crossover_and_select(self):
        for i in range(self.size):
            Jrand = random.randint(0, self.dimension)
            for j in range(self.dimension):
                if random.random() > self.CR and j != Jrand:
                    self.mutant[i][j] = self.individuality[i][j]
                tmp = self.get_object_function_value(self.mutant[i])
                if tmp < self.object_function_values[i]:
                    self.individuality[i] = self.mutant[i]
                    self.object_function_values[i] = tmp

    def print_best(self):
        m = min(self.object_function_values)
        i = self.object_function_values.index(m)
        print("轮数：" + str(self.cur_round))
        print("最佳个体：" + str(self.individuality[i]))
        print("目标函数值：" + str(m))

    def evolution(self):
        while self.cur_round < self.rounds:
            self.mutate()
            self.crossover_and_select()
            self.print_best()
            self.cur_round = self.cur_round + 1

class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")
        super(attention, self).build(input_shape)

    def call(self, x):
        et = tensorflow.squeeze(keras.activations.sigmoid(tf.matmul(x, self.W) + self.b), axis=-1)

        at = at = tf.keras.activations.softmax(et)

        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()


def model_lstm_att(time_steps, input_dim, n_units):
    K.clear_session()  # 清除之前的模型，省得压满内存
    model_input = Input(shape=(time_steps, input_dim))
    x = LSTM(n_units, return_sequences=True)(model_input)
    x = attention()(x)
    x = Dense(1)(x)
    model = Model(model_input, x)
    return model
def model_lstm(seq_len, n_features, n_units):
    model = Sequential()
    model.add(LSTM(n_units, activation="relu", input_shape=(seq_len, n_features)))
    model.add(Dense(1))
    return model

def evaluation(real, pre):
    rmse = mean_squared_error(real, pre, squared=False)
    mae = mean_absolute_error(real, pre)
    mape = mean_absolute_percentage_error(real, pre)
    r2 = r2_score(real, pre)
    var = 1-(np.var(real - pre))/np.var(real)
    F_norm = la.norm(real-pre)/la.norm(real)

    return rmse, mae, mape, r2, var, 1-F_norm

def min_max_scaler(li):
    min_ = min(li)
    max_ = max(li)
    ret = [(i - min_) / (max_ - min_) for i in li]
    return ret, min_, max_

def data_split(data, train_rate, seq_len, pre_len=1):
    time_len, n_feature = data.shape
    train_size = int(time_len * train_rate)
    train_data = data[0:train_size]
    trainX, trainY, testX, testY = [], [], [], []
    for i in range(train_size-seq_len-pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0: seq_len])
        trainY.append(a[seq_len: seq_len + pre_len, 0])
    for i in range(train_size-seq_len-pre_len, time_len-pre_len-seq_len):
        b = data[i: i+seq_len+pre_len,:]
        testX.append(b[0:seq_len])
        testY.append(b[seq_len:seq_len+pre_len, 0])
    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

def lstm(n_units=64, seq_len=10, batch_size=64):
    error_list = []

    rmse_list = []
    mae_list = []
    mape_list = []
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        important = True
        if important:
            file = open(r"E:\\MiniProject\exchange_anomaly_detection-main\exchange\\feature\\" + exchange + '_ft.csv')
        else:
            file = open(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\feature\\" + exchange + '_ft_not_important.csv')
        df = pd.read_csv(file)

        data = df.values
        # print("type data")
        # print(type(data))
        time_len, n_features = data.shape
        train_rate = 0.8
        train_size = int(time_len*train_rate)
        trainX, trainY, testX, testY = data_split(data, train_rate=train_rate, seq_len=seq_len)
        scaled_data = data.copy()
        # 对每一列特征进行归一化
        scaler = []
        for j in range(n_features):
            temp_scaler = MinMaxScaler(feature_range=(0, 1))
            temp = temp_scaler.fit_transform(np.array(scaled_data[:, j]).reshape(-1,1))
            scaler.append(temp_scaler)
            temp = temp.reshape(-1)
            scaled_data[:, j] = temp
        trainX1, trainY1, testX1, testY1 = data_split(scaled_data, train_rate=train_rate, seq_len=seq_len)

        model_name = "LSTM_attention"
        if model_name=="LSTM_attention":
            model = model_lstm_att(seq_len, n_features, n_units)
        if model_name=="LSTM":
            model = model_lstm(seq_len, n_features, n_units)

        opt = optimizers.Adam()
        model.compile(optimizer=opt, loss='mse')
        history = model.fit(trainX1, trainY1, epochs=50, batch_size=batch_size, validation_data=(testX1, testY1), verbose=2, shuffle=False)
        # 绘制历史数据
        if False:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(history.history['loss'], label='train')
            plt.plot(history.history['val_loss'], label='test')
            plt.legend()
            plt.title(exchange)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange/figure/lstm_prediction" + exchange + '_' + model_name + '_loss.png')
            plt.show()
        prediction_val = model.predict(testX1)
        # print(type(prediction_val))
        # print(prediction_val)

        rmse, mae, mape, r2, var, _ = evaluation(testY1, prediction_val)
        print("rmse = {}\nmae = {}\nmape = {}\nr2 = {}\nvar = {}\n".format(rmse, mae, mape, r2, var))
        error_list.append("rmse = {}\nmae = {}\nmape = {}\n".format(rmse, mae, mape))

        rmse_list.append(rmse)
        mae_list.append(mae)
        mape_list.append(mape)

        prediction_val = np.array(scaled_data[0:train_size, 0].tolist()+prediction_val[:, 0].tolist())
        prediction_val = prediction_val.reshape(-1,1)
        prediction_val = scaler[0].inverse_transform(prediction_val)
        prediction_val = prediction_val[train_size:,0]
        print("testY")
        testY = testY[:,0]
        print("testY.shape")
        print(testY.shape)
        print(type(testY))
        print("prediction_val")
        print(prediction_val.shape)
        print(type(prediction_val))

        if False:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(range(time_len-train_size), testY)
            plt.plot(range(time_len-train_size), np.array(prediction_val))
            upper_bound = [it + 3 * np.std(testY) for it in prediction_val]
            lower_bound = [it - 3 * np.std(testY) for it in prediction_val]
            abnormal_x = []
            abnormal_y = []
            for j in range(len(upper_bound)):
                if testY[j]>upper_bound[j]:
                    abnormal_x.append(j)
                    abnormal_y.append(testY[j])
            print(exchange)
            print("abnormal_x")
            print(abnormal_x)
            print("abnormal_y")
            print(abnormal_y)
            print("train_size+x")
            print([it+train_size for it in abnormal_x])
            plt.plot(range(time_len-train_size), upper_bound, "--")
            plt.plot(range(time_len-train_size), lower_bound, "--")
            plt.scatter(abnormal_x, abnormal_y, c="r", marker="x")
            plt.legend(("real", model_name, "upper_bound", "lower_bound", "abnormal_detected"), loc=2)
            plt.title(exchange)
            plt.xlabel("Days")
            plt.ylabel("Transaction Amount(USD)")
            plt.savefig('./exchange/figure/lstm_prediction_' + exchange + '_' + model_name + '_prediction.png')
            plt.show()
    for i in range(len(exchanges)):
        print(exchanges[i])
        print(error_list[i])
    return rmse_list, mae_list, mape_list

def parameter_sensitivity(parameter, para_range):
    rmse_list = [[] for i in range(len(exchanges))] #第一维表示不同交易所，第二位表示不同的参数对应的值
    mae_list = [[] for i in range(len(exchanges))]
    mape_list = [[] for i in range(len(exchanges))]
    for it in para_range:
        if parameter=="n_units":
            temp_rmse, temp_mae, temp_mape = lstm(n_units=it)
        if parameter=="seq_len":
            temp_rmse, temp_mae, temp_mape = lstm(seq_len=it)
        if parameter == "batch_size":
            temp_rmse, temp_mae, temp_mape = lstm(batch_size=it)
        for jj in range(len(temp_rmse)):
            rmse_list[jj].append(temp_rmse[jj])
            mae_list[jj].append(temp_mae[jj])
            mape_list[jj].append(temp_mape[jj])
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        rmse_list[i],_,_ = min_max_scaler(rmse_list[i])
        mae_list[i],_,_ = min_max_scaler(mae_list[i])
        mape_list[i],_,_ = min_max_scaler(mape_list[i])
        plt.figure()
        plt.grid(linestyle="--")
        plt.plot(para_range, rmse_list[i])
        plt.plot(para_range, mae_list[i])
        plt.plot(para_range, mape_list[i])
        plt.legend(("RMSE", "MAE", "MAPE"))
        plt.xlabel(parameter)
        plt.ylabel("Normalised Values")
        plt.title(exchange)
        plt.savefig('./exchange/figure/para_' + parameter + '_' + exchange + '.png')
        plt.show()

def cal_date():
    li = []
    li.append([1400, 1415, 1416, 1420, 1421, 1543])
    li.append([222])
    li.append([1413, 1450, 1501])
    li.append([2097, 2111, 2113])
    li.append([1463, 1503, 1522, 1542])
    start_time = [1499212800, 1619481600, 1495497600, 1438905600, 1505606400]
    for i in range(len(li)):
        print(exchanges[i])
        for j in range(len(li[i])):
            temp_time = start_time[i] + li[i][j]*86400
            timeArray = time.localtime(temp_time)
            otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
            print(otherStyleTime)

constraint_eq = [
    lambda x: 1 - x[1] - x[2]
]

constraint_ueq = [
    lambda x: 1 - x[0] * x[1],
    lambda x: x[0] * x[1] - 5
]
if __name__=='__main__':
    def f(v):
        v0,v1,v2 = v
        temp_rmse, temp_mae, temp_mape = lstm(round(v0), round(v1), round(v2))
        ret = 0
        for jj in range(len(temp_rmse)):
            ret += temp_rmse[jj]
        return ret
    start = time.perf_counter()

    de = DE(func=f, n_dim=3, size_pop=20, max_iter=100, lb=[8, 5, 8], ub=[128, 80, 128])
    best_x, best_y = de.run()
    elapsed = (time.clock() - start)
    print('best_x:', best_x, '\n', 'best_y:', best_y)
    print("Time used:", elapsed)
    # lstm()
    # parameter_sensitivity("seq_len", [5, 10, 20, 40, 80])
    # cal_date()
# Out:
# Epoch 1/50
# 13/13 - 2s - 182ms/step - loss: 9.7342e-04 - val_loss: 0.0502
# Epoch 2/50
# 13/13 - 0s - 19ms/step - loss: 0.0033 - val_loss: 0.0381
# Epoch 3/50
# 13/13 - 0s - 17ms/step - loss: 0.0034 - val_loss: 0.0200
# Epoch 4/50
# 13/13 - 0s - 19ms/step - loss: 0.0011 - val_loss: 0.0163
# Epoch 5/50
# 13/13 - 0s - 19ms/step - loss: 8.4755e-04 - val_loss: 0.0130
# Epoch 6/50
# 13/13 - 0s - 19ms/step - loss: 5.4961e-04 - val_loss: 0.0156
# Epoch 7/50
# 13/13 - 0s - 20ms/step - loss: 5.7269e-04 - val_loss: 0.0127
# Epoch 8/50
# 13/13 - 0s - 20ms/step - loss: 4.6298e-04 - val_loss: 0.0134
# Epoch 9/50
# 13/13 - 0s - 19ms/step - loss: 3.9664e-04 - val_loss: 0.0125
# Epoch 10/50
# 13/13 - 0s - 18ms/step - loss: 3.9495e-04 - val_loss: 0.0129
# Epoch 11/50
# 13/13 - 0s - 19ms/step - loss: 3.3641e-04 - val_loss: 0.0126
# Epoch 12/50
# 13/13 - 0s - 19ms/step - loss: 3.3699e-04 - val_loss: 0.0127
# Epoch 13/50
# 13/13 - 0s - 22ms/step - loss: 2.5045e-04 - val_loss: 0.0129
# Epoch 44/50
# 13/13 - 0s - 19ms/step - loss: 2.4244e-04 - val_loss: 0.0130
# Epoch 45/50
# 13/13 - 0s - 18ms/step - loss: 2.3841e-04 - val_loss: 0.0131
# Epoch 46/50
# 13/13 - 0s - 19ms/step - loss: 2.3596e-04 - val_loss: 0.0133
# Epoch 47/50
# 13/13 - 0s - 21ms/step - loss: 2.3182e-04 - val_loss: 0.0134
# Epoch 48/50
# 13/13 - 0s - 19ms/step - loss: 2.3120e-04 - val_loss: 0.0136
# Epoch 49/50
# 13/13 - 0s - 22ms/step - loss: 2.2824e-04 - val_loss: 0.0138
# Epoch 50/50
# 13/13 - 0s - 18ms/step - loss: 2.2676e-04 - val_loss: 0.0140
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# rmse = 0.11811942905792791
# mae = 0.09307666608386998
# mape = 0.7011495378838858
# r2 = 0.048501488534147486
# var = 0.2014215772531599
#
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 2/2 - 2s - 1s/step - loss: 0.0464 - val_loss: 0.0167
# Epoch 2/50
# 2/2 - 0s - 37ms/step - loss: 0.0125 - val_loss: 0.0685
# Epoch 3/50
# 2/2 - 0s - 34ms/step - loss: 0.0255 - val_loss: 0.0541
# Epoch 4/50
# 2/2 - 0s - 35ms/step - loss: 0.0197 - val_loss: 0.0227
# Epoch 5/50
# 2/2 - 0s - 33ms/step - loss: 0.0122 - val_loss: 0.0134
# Epoch 6/50
# 2/2 - 0s - 33ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 7/50
# 2/2 - 0s - 32ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 8/50
# 2/2 - 0s - 34ms/step - loss: 0.0140 - val_loss: 0.0134
# Epoch 9/50
# 2/2 - 0s - 33ms/step - loss: 0.0118 - val_loss: 0.0160
# Epoch 10/50
# 2/2 - 0s - 39ms/step - loss: 0.0111 - val_loss: 0.0224
# Epoch 11/50
# 2/2 - 0s - 33ms/step - loss: 0.0120 - val_loss: 0.0271
# Epoch 12/50
# 2/2 - 0s - 34ms/step - loss: 0.0128 - val_loss: 0.0264
# Epoch 13/50
# 2/2 - 0s - 29ms/step - loss: 0.0123 - val_loss: 0.0219
# Epoch 14/50
# 2/2 - 0s - 33ms/step - loss: 0.0114 - val_loss: 0.0175
# Epoch 15/50
# 2/2 - 0s - 38ms/step - loss: 0.0111 - val_loss: 0.0152
# Epoch 16/50
# 2/2 - 0s - 37ms/step - loss: 0.0113 - val_loss: 0.0146
# Epoch 17/50
# 2/2 - 0s - 35ms/step - loss: 0.0114 - val_loss: 0.0150
# Epoch 18/50
# 2/2 - 0s - 34ms/step - loss: 0.0112 - val_loss: 0.0167
# Epoch 19/50
# 2/2 - 0s - 37ms/step - loss: 0.0110 - val_loss: 0.0195
# Epoch 20/50
# 2/2 - 0s - 37ms/step - loss: 0.0109 - val_loss: 0.0223
# Epoch 21/50
# 2/2 - 0s - 33ms/step - loss: 0.0111 - val_loss: 0.0237
# Epoch 22/50
# 2/2 - 0s - 38ms/step - loss: 0.0111 - val_loss: 0.0231
# Epoch 23/50
# 2/2 - 0s - 33ms/step - loss: 0.0110 - val_loss: 0.0214
# Epoch 24/50
# 2/2 - 0s - 38ms/step - loss: 0.0109 - val_loss: 0.0198
# Epoch 25/50
# 2/2 - 0s - 33ms/step - loss: 0.0109 - val_loss: 0.0190
# Epoch 26/50
# 2/2 - 0s - 45ms/step - loss: 0.0109 - val_loss: 0.0192
# Epoch 27/50
# 2/2 - 0s - 33ms/step - loss: 0.0109 - val_loss: 0.0204
# Epoch 28/50
# 2/2 - 0s - 30ms/step - loss: 0.0109 - val_loss: 0.0222
# Epoch 29/50
# 2/2 - 0s - 38ms/step - loss: 0.0108 - val_loss: 0.0238
# Epoch 30/50
# 2/2 - 0s - 35ms/step - loss: 0.0108 - val_loss: 0.0246
# Epoch 31/50
# 2/2 - 0s - 37ms/step - loss: 0.0108 - val_loss: 0.0244
# Epoch 32/50
# 2/2 - 0s - 38ms/step - loss: 0.0108 - val_loss: 0.0236
# Epoch 33/50
# 2/2 - 0s - 35ms/step - loss: 0.0108 - val_loss: 0.0230
# Epoch 34/50
# 2/2 - 0s - 33ms/step - loss: 0.0108 - val_loss: 0.0229
# Epoch 35/50
# 2/2 - 0s - 30ms/step - loss: 0.0108 - val_loss: 0.0235
# Epoch 36/50
# 2/2 - 0s - 34ms/step - loss: 0.0108 - val_loss: 0.0245
# Epoch 37/50
# 2/2 - 0s - 34ms/step - loss: 0.0108 - val_loss: 0.0256
# Epoch 38/50
# 2/2 - 0s - 34ms/step - loss: 0.0108 - val_loss: 0.0262
# Epoch 39/50
# 2/2 - 0s - 36ms/step - loss: 0.0108 - val_loss: 0.0264
# Epoch 40/50
# 2/2 - 0s - 36ms/step - loss: 0.0108 - val_loss: 0.0261
# Epoch 41/50
# 2/2 - 0s - 33ms/step - loss: 0.0108 - val_loss: 0.0259
# Epoch 42/50
# 2/2 - 0s - 37ms/step - loss: 0.0108 - val_loss: 0.0260
# Epoch 43/50
# 2/2 - 0s - 33ms/step - loss: 0.0108 - val_loss: 0.0265
# Epoch 44/50
# 2/2 - 0s - 34ms/step - loss: 0.0107 - val_loss: 0.0272
# Epoch 45/50
# 2/2 - 0s - 33ms/step - loss: 0.0107 - val_loss: 0.0279
# Epoch 46/50
# 2/2 - 0s - 33ms/step - loss: 0.0107 - val_loss: 0.0284
# Epoch 47/50
# 2/2 - 0s - 34ms/step - loss: 0.0107 - val_loss: 0.0286
# Epoch 48/50
# 2/2 - 0s - 33ms/step - loss: 0.0107 - val_loss: 0.0286
# Epoch 49/50
# 2/2 - 0s - 41ms/step - loss: 0.0107 - val_loss: 0.0287
# Epoch 50/50
# 2/2 - 0s - 34ms/step - loss: 0.0107 - val_loss: 0.0291
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# rmse = 0.1705757911644661
# mae = 0.14136376205648463
# mape = 1.0983886719996003
# r2 = -1.1579994635533648
# var = -0.10797080424863292
#
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 13/13 - 2s - 181ms/step - loss: 1.5542e-04 - val_loss: 0.0078
# Epoch 2/50
# 13/13 - 0s - 19ms/step - loss: 1.1028e-04 - val_loss: 0.0078
# Epoch 3/50
# 13/13 - 0s - 19ms/step - loss: 1.2173e-04 - val_loss: 0.0092
# Epoch 4/50
# 13/13 - 0s - 19ms/step - loss: 1.3632e-04 - val_loss: 0.0117
# Epoch 5/50
# 13/13 - 0s - 19ms/step - loss: 2.3951e-04 - val_loss: 0.0083
# Epoch 6/50
# 13/13 - 0s - 19ms/step - loss: 3.2843e-04 - val_loss: 0.0060
# Epoch 7/50
# 13/13 - 0s - 19ms/step - loss: 7.0015e-04 - val_loss: 0.0111
# Epoch 8/50
# 13/13 - 0s - 19ms/step - loss: 4.1091e-04 - val_loss: 0.0108
# Epoch 9/50
# 13/13 - 0s - 20ms/step - loss: 2.3646e-04 - val_loss: 0.0075
# Epoch 10/50
# 13/13 - 0s - 19ms/step - loss: 1.2204e-04 - val_loss: 0.0081
# Epoch 11/50
# 13/13 - 0s - 19ms/step - loss: 1.0992e-04 - val_loss: 0.0086
# Epoch 12/50
# 13/13 - 0s - 19ms/step - loss: 1.0444e-04 - val_loss: 0.0083
# Epoch 13/50
# 13/13 - 0s - 19ms/step - loss: 1.0381e-04 - val_loss: 0.0085
# Epoch 14/50
# 13/13 - 0s - 19ms/step - loss: 1.0331e-04 - val_loss: 0.0083
# Epoch 15/50
# 13/13 - 0s - 19ms/step - loss: 1.0316e-04 - val_loss: 0.0083
# Epoch 16/50
# 13/13 - 0s - 20ms/step - loss: 1.0299e-04 - val_loss: 0.0081
# Epoch 17/50
# 13/13 - 0s - 19ms/step - loss: 1.0294e-04 - val_loss: 0.0081
# Epoch 18/50
# 13/13 - 0s - 19ms/step - loss: 1.0286e-04 - val_loss: 0.0081
# Epoch 19/50
# 13/13 - 0s - 19ms/step - loss: 1.0280e-04 - val_loss: 0.0080
# Epoch 20/50
# 13/13 - 0s - 19ms/step - loss: 1.0274e-04 - val_loss: 0.0080
# Epoch 21/50
# 13/13 - 0s - 18ms/step - loss: 1.0268e-04 - val_loss: 0.0080
# Epoch 22/50
# 13/13 - 0s - 19ms/step - loss: 1.0262e-04 - val_loss: 0.0079
# Epoch 23/50
# 13/13 - 0s - 21ms/step - loss: 1.0256e-04 - val_loss: 0.0079
# Epoch 24/50
# 13/13 - 0s - 22ms/step - loss: 1.0250e-04 - val_loss: 0.0079
# Epoch 25/50
# 13/13 - 0s - 19ms/step - loss: 1.0244e-04 - val_loss: 0.0079
# Epoch 26/50
# 13/13 - 0s - 20ms/step - loss: 1.0238e-04 - val_loss: 0.0079
# Epoch 27/50
# 13/13 - 0s - 18ms/step - loss: 1.0231e-04 - val_loss: 0.0079
# Epoch 28/50
# 13/13 - 0s - 20ms/step - loss: 1.0224e-04 - val_loss: 0.0078
# Epoch 29/50
# 13/13 - 0s - 18ms/step - loss: 1.0217e-04 - val_loss: 0.0078
# Epoch 30/50
# 13/13 - 0s - 19ms/step - loss: 1.0210e-04 - val_loss: 0.0078
# Epoch 31/50
# 13/13 - 0s - 19ms/step - loss: 1.0202e-04 - val_loss: 0.0078
# Epoch 32/50
# 13/13 - 0s - 19ms/step - loss: 1.0194e-04 - val_loss: 0.0078
# Epoch 33/50
# 13/13 - 0s - 20ms/step - loss: 1.0186e-04 - val_loss: 0.0078
# Epoch 34/50
# 13/13 - 0s - 20ms/step - loss: 1.0177e-04 - val_loss: 0.0078
# Epoch 35/50
# 13/13 - 0s - 19ms/step - loss: 1.0168e-04 - val_loss: 0.0078
# Epoch 36/50
# 13/13 - 0s - 19ms/step - loss: 1.0159e-04 - val_loss: 0.0078
# Epoch 37/50
# 13/13 - 0s - 19ms/step - loss: 1.0150e-04 - val_loss: 0.0078
# Epoch 38/50
# 13/13 - 0s - 21ms/step - loss: 1.0140e-04 - val_loss: 0.0078
# Epoch 39/50
# 13/13 - 0s - 18ms/step - loss: 1.0129e-04 - val_loss: 0.0077
# Epoch 40/50
# 13/13 - 0s - 20ms/step - loss: 1.0118e-04 - val_loss: 0.0077
# Epoch 41/50
# 13/13 - 0s - 21ms/step - loss: 1.0107e-04 - val_loss: 0.0077
# Epoch 42/50
# 13/13 - 0s - 19ms/step - loss: 1.0095e-04 - val_loss: 0.0077
# Epoch 43/50
# 13/13 - 0s - 18ms/step - loss: 1.0082e-04 - val_loss: 0.0077
# Epoch 44/50
# 13/13 - 0s - 18ms/step - loss: 1.0069e-04 - val_loss: 0.0077
# Epoch 45/50
# 13/13 - 0s - 18ms/step - loss: 1.0055e-04 - val_loss: 0.0077
# Epoch 46/50
# 13/13 - 0s - 20ms/step - loss: 1.0040e-04 - val_loss: 0.0077
# Epoch 47/50
# 13/13 - 0s - 19ms/step - loss: 1.0025e-04 - val_loss: 0.0077
# Epoch 48/50
# 13/13 - 0s - 19ms/step - loss: 1.0008e-04 - val_loss: 0.0077
# Epoch 49/50
# 13/13 - 0s - 18ms/step - loss: 9.9911e-05 - val_loss: 0.0077
# Epoch 50/50
# 13/13 - 0s - 20ms/step - loss: 9.9726e-05 - val_loss: 0.0077
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024002754540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# rmse = 0.08751871107623299
# mae = 0.04688137040280791
# mape = 0.6668643834393722
# r2 = -0.3745706122280461
# var = 0.016377247219660718
#
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 18/18 - 2s - 134ms/step - loss: 0.0016 - val_loss: 0.0479
# Epoch 2/50
# 18/18 - 0s - 19ms/step - loss: 0.0022 - val_loss: 0.0188
# Epoch 3/50
# 18/18 - 0s - 19ms/step - loss: 0.0023 - val_loss: 0.0568
# Epoch 4/50
# 18/18 - 0s - 19ms/step - loss: 9.1963e-04 - val_loss: 0.0271
# Epoch 5/50
# 18/18 - 0s - 18ms/step - loss: 9.1200e-04 - val_loss: 0.0229
# Epoch 6/50
# 18/18 - 0s - 18ms/step - loss: 8.1828e-04 - val_loss: 0.0338
# Epoch 7/50
# 18/18 - 0s - 18ms/step - loss: 7.4631e-04 - val_loss: 0.0238
# Epoch 8/50
# 18/18 - 0s - 19ms/step - loss: 6.5261e-04 - val_loss: 0.0270
# Epoch 39/50
# 18/18 - 0s - 19ms/step - loss: 6.1078e-04 - val_loss: 0.0395
# Epoch 40/50
# 18/18 - 0s - 18ms/step - loss: 6.0944e-04 - val_loss: 0.0404
# Epoch 41/50
# 18/18 - 0s - 18ms/step - loss: 6.0878e-04 - val_loss: 0.0417
# Epoch 42/50
# 18/18 - 0s - 20ms/step - loss: 6.0812e-04 - val_loss: 0.0433
# Epoch 43/50
# 18/18 - 0s - 18ms/step - loss: 6.0654e-04 - val_loss: 0.0442
# Epoch 44/50
# 18/18 - 0s - 18ms/step - loss: 6.0578e-04 - val_loss: 0.0456
# Epoch 45/50
# 18/18 - 0s - 18ms/step - loss: 6.0563e-04 - val_loss: 0.0477
# Epoch 46/50
# 18/18 - 0s - 18ms/step - loss: 6.0348e-04 - val_loss: 0.0488
# Epoch 47/50
# 18/18 - 0s - 18ms/step - loss: 6.0247e-04 - val_loss: 0.0498
# Epoch 48/50
# 18/18 - 0s - 18ms/step - loss: 6.0376e-04 - val_loss: 0.0530
# Epoch 49/50
# 18/18 - 0s - 19ms/step - loss: 6.0044e-04 - val_loss: 0.0546
# Epoch 50/50
# 18/18 - 0s - 18ms/step - loss: 5.9987e-04 - val_loss: 0.0537
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# rmse = 0.23175110371773278
# mae = 0.15488556395262615
# mape = 0.8484674997816585
# r2 = -0.5745971337140432
# var = 0.12465570052246311
#
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 12/12 - 2s - 187ms/step - loss: 0.0014 - val_loss: 0.0249
# Epoch 2/50
# 12/12 - 0s - 20ms/step - loss: 8.9320e-04 - val_loss: 0.0130
# Epoch 3/50
# 12/12 - 0s - 19ms/step - loss: 7.4949e-04 - val_loss: 0.0107
# Epoch 4/50
# 12/12 - 0s - 19ms/step - loss: 7.5552e-04 - val_loss: 0.0098
# Epoch 5/50
# 12/12 - 0s - 19ms/step - loss: 7.0931e-04 - val_loss: 0.0080
# Epoch 6/50
# 12/12 - 0s - 19ms/step - loss: 6.7026e-04 - val_loss: 0.0078
# Epoch 7/50
# 12/12 - 0s - 19ms/step - loss: 6.5827e-04 - val_loss: 0.0080
# Epoch 8/50
# 12/12 - 0s - 19ms/step - loss: 6.4582e-04 - val_loss: 0.0086
# Epoch 9/50
# 12/12 - 0s - 18ms/step - loss: 6.2156e-04 - val_loss: 0.0104
# Epoch 10/50
# 12/12 - 0s - 19ms/step - loss: 5.9559e-04 - val_loss: 0.0119
# Epoch 11/50
# 12/12 - 0s - 19ms/step - loss: 5.8331e-04 - val_loss: 0.0125
# Epoch 12/50
# 12/12 - 0s - 20ms/step - loss: 5.9510e-04 - val_loss: 0.0133
# Epoch 13/50
# 12/12 - 0s - 19ms/step - loss: 5.8316e-04 - val_loss: 0.0152
# Epoch 14/50
# 12/12 - 0s - 19ms/step - loss: 5.8102e-04 - val_loss: 0.0178
# Epoch 15/50
# 12/12 - 0s - 18ms/step - loss: 6.3443e-04 - val_loss: 0.0194
# Epoch 16/50
# 12/12 - 0s - 18ms/step - loss: 6.0437e-04 - val_loss: 0.0132
# 12/12 - 0s - 19ms/step - loss: 5.9946e-04 - val_loss: 0.0115
# Epoch 47/50
# 12/12 - 0s - 19ms/step - loss: 5.3012e-04 - val_loss: 0.0152
# Epoch 48/50
# 12/12 - 0s - 19ms/step - loss: 4.6029e-04 - val_loss: 0.0127
# Epoch 49/50
# 12/12 - 0s - 19ms/step - loss: 4.7521e-04 - val_loss: 0.0179
# Epoch 50/50
# 12/12 - 0s - 21ms/step - loss: 4.3879e-04 - val_loss: 0.0163
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# rmse = 0.1276173067216507
# mae = 0.09928008894824551
# mape = 0.8265914466074119
# r2 = -0.30808896943521136
# var = 0.21100265987613742
#
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.11811942905792791
# mae = 0.09307666608386998
# mape = 0.7011495378838858
#
# coinbase
# rmse = 0.1705757911644661
# mae = 0.14136376205648463
# mape = 1.0983886719996003
#
# huobi
# rmse = 0.08751871107623299
# mae = 0.04688137040280791
# mape = 0.6668643834393722
#
# kraken
# rmse = 0.23175110371773278
# mae = 0.15488556395262615
# mape = 0.8484674997816585
#
# kucoin
# rmse = 0.1276173067216507
# mae = 0.09928008894824551
# mape = 0.8265914466074119
#
# Epoch 1/50
# 36/36 - 3s - 88ms/step - loss: 7.2040e-04 - val_loss: 0.0233
# Epoch 2/50
# 36/36 - 1s - 24ms/step - loss: 0.0015 - val_loss: 0.0246
# Epoch 3/50
# 36/36 - 1s - 25ms/step - loss: 0.0017 - val_loss: 0.0530
# Epoch 4/50
# 36/36 - 1s - 25ms/step - loss: 0.0016 - val_loss: 0.0603
# Epoch 5/50
# 36/36 - 1s - 25ms/step - loss: 0.0013 - val_loss: 0.0473
# Epoch 6/50
# 36/36 - 1s - 26ms/step - loss: 9.3620e-04 - val_loss: 0.0246
# Epoch 7/50
# 36/36 - 1s - 25ms/step - loss: 0.0012 - val_loss: 0.0180
# Epoch 8/50
# 36/36 - 1s - 26ms/step - loss: 0.0010 - val_loss: 0.0154
# Epoch 9/50
# 36/36 - 1s - 29ms/step - loss: 4.4990e-04 - val_loss: 0.0156
# Epoch 10/50
# 36/36 - 1s - 28ms/step - loss: 3.6660e-04 - val_loss: 0.0177
# Epoch 11/50
# 36/36 - 1s - 29ms/step - loss: 4.0716e-04 - val_loss: 0.0157
# Epoch 12/50
# 36/36 - 1s - 25ms/step - loss: 4.6246e-04 - val_loss: 0.0140
# Epoch 13/50
# 36/36 - 1s - 25ms/step - loss: 4.0759e-04 - val_loss: 0.0139
# Epoch 14/50
# 36/36 - 1s - 25ms/step - loss: 3.4607e-04 - val_loss: 0.0143
# Epoch 15/50
# 36/36 - 1s - 25ms/step - loss: 3.5020e-04 - val_loss: 0.0140
# Epoch 16/50
# 36/36 - 1s - 27ms/step - loss: 3.8385e-04 - val_loss: 0.0140
# Epoch 17/50
# 36/36 - 1s - 26ms/step - loss: 3.8758e-04 - val_loss: 0.0148
# Epoch 18/50
# 36/36 - 1s - 26ms/step - loss: 3.5322e-04 - val_loss: 0.0162
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# rmse = 0.15463615107345174
# mae = 0.13131222249167296
# mape = 1.0575201021965746
# r2 = -0.6307504159589545
# var = 0.04220110156521284
#
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 4/4 - 2s - 558ms/step - loss: 0.0207 - val_loss: 0.0511
# Epoch 2/50
# 4/4 - 0s - 35ms/step - loss: 0.0187 - val_loss: 0.0276
# Epoch 3/50
# 4/4 - 0s - 31ms/step - loss: 0.0143 - val_loss: 0.0150
# Epoch 4/50
# 4/4 - 0s - 31ms/step - loss: 0.0134 - val_loss: 0.0291
# Epoch 5/50
# 4/4 - 0s - 32ms/step - loss: 0.0133 - val_loss: 0.0381
# Epoch 6/50
# 4/4 - 0s - 31ms/step - loss: 0.0132 - val_loss: 0.0232
# Epoch 7/50
# 4/4 - 0s - 35ms/step - loss: 0.0127 - val_loss: 0.0212
# Epoch 8/50
# 4/4 - 0s - 33ms/step - loss: 0.0125 - val_loss: 0.0302
# Epoch 9/50
# 4/4 - 0s - 35ms/step - loss: 0.0126 - val_loss: 0.0327
# Epoch 10/50
# 4/4 - 0s - 29ms/step - loss: 0.0125 - val_loss: 0.0261
# Epoch 11/50
# 4/4 - 0s - 31ms/step - loss: 0.0124 - val_loss: 0.0260
# Epoch 12/50
# 4/4 - 0s - 31ms/step - loss: 0.0123 - val_loss: 0.0310
# Epoch 13/50
# 4/4 - 0s - 31ms/step - loss: 0.0124 - val_loss: 0.0306
# Epoch 14/50
# 4/4 - 0s - 36ms/step - loss: 0.0123 - val_loss: 0.0277
# Epoch 15/50
# 4/4 - 0s - 32ms/step - loss: 0.0123 - val_loss: 0.0292
# Epoch 16/50
# 4/4 - 0s - 31ms/step - loss: 0.0122 - val_loss: 0.0311
# Epoch 17/50
# 4/4 - 0s - 35ms/step - loss: 0.0122 - val_loss: 0.0297
# Epoch 18/50
# 4/4 - 0s - 33ms/step - loss: 0.0122 - val_loss: 0.0296
# Epoch 19/50
# 4/4 - 0s - 31ms/step - loss: 0.0122 - val_loss: 0.0312
# Epoch 20/50
# 4/4 - 0s - 35ms/step - loss: 0.0122 - val_loss: 0.0309
# Epoch 21/50
# 4/4 - 0s - 35ms/step - loss: 0.0121 - val_loss: 0.0307
# Epoch 22/50
# 4/4 - 0s - 32ms/step - loss: 0.0121 - val_loss: 0.0319
# Epoch 23/50
# 4/4 - 0s - 33ms/step - loss: 0.0121 - val_loss: 0.0319
# Epoch 24/50
# 4/4 - 0s - 34ms/step - loss: 0.0120 - val_loss: 0.0322
# Epoch 25/50
# 4/4 - 0s - 31ms/step - loss: 0.0120 - val_loss: 0.0331
# Epoch 26/50
# 4/4 - 0s - 32ms/step - loss: 0.0120 - val_loss: 0.0331
# Epoch 27/50
# 4/4 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0340
# Epoch 28/50
# 4/4 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0344
# Epoch 29/50
# 4/4 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0353
# Epoch 30/50
# 4/4 - 0s - 32ms/step - loss: 0.0119 - val_loss: 0.0362
# Epoch 31/50
# 4/4 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0379
# Epoch 32/50
# 4/4 - 0s - 35ms/step - loss: 0.0119 - val_loss: 0.0398
# Epoch 33/50
# 4/4 - 0s - 32ms/step - loss: 0.0118 - val_loss: 0.0427
# Epoch 34/50
# 4/4 - 0s - 32ms/step - loss: 0.0118 - val_loss: 0.0454
# Epoch 35/50
# 4/4 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0488
# Epoch 36/50
# 4/4 - 0s - 35ms/step - loss: 0.0118 - val_loss: 0.0520
# Epoch 37/50
# 4/4 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0556
# Epoch 38/50
# 4/4 - 0s - 32ms/step - loss: 0.0118 - val_loss: 0.0591
# Epoch 39/50
# 4/4 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0631
# Epoch 40/50
# 4/4 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0673
# Epoch 41/50
# 4/4 - 0s - 35ms/step - loss: 0.0118 - val_loss: 0.0721
# Epoch 42/50
# 4/4 - 0s - 32ms/step - loss: 0.0117 - val_loss: 0.0773
# Epoch 43/50
# 4/4 - 0s - 35ms/step - loss: 0.0117 - val_loss: 0.0829
# Epoch 44/50
# 4/4 - 0s - 35ms/step - loss: 0.0117 - val_loss: 0.0890
# Epoch 45/50
# 4/4 - 0s - 31ms/step - loss: 0.0117 - val_loss: 0.0956
# Epoch 46/50
# 4/4 - 0s - 35ms/step - loss: 0.0117 - val_loss: 0.1028
# Epoch 47/50
# 4/4 - 0s - 31ms/step - loss: 0.0117 - val_loss: 0.1105
# Epoch 48/50
# 4/4 - 0s - 31ms/step - loss: 0.0117 - val_loss: 0.1187
# Epoch 49/50
# 4/4 - 0s - 35ms/step - loss: 0.0117 - val_loss: 0.1274
# Epoch 50/50
# 4/4 - 0s - 32ms/step - loss: 0.0117 - val_loss: 0.1363
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# rmse = 0.3691281011754519
# mae = 0.322120464560239
# mape = 2.331897572647243
# r2 = -9.105801443943582
# var = -1.5683118162421894
#
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 34/34 - 3s - 88ms/step - loss: 1.9779e-04 - val_loss: 0.0097
# Epoch 2/50
# 34/34 - 1s - 27ms/step - loss: 1.5509e-04 - val_loss: 0.0114
# Epoch 3/50
# 34/34 - 1s - 25ms/step - loss: 1.8859e-04 - val_loss: 0.0145
# Epoch 4/50
# 34/34 - 1s - 25ms/step - loss: 2.3844e-04 - val_loss: 0.0080
# Epoch 5/50
# 34/34 - 1s - 25ms/step - loss: 1.2784e-04 - val_loss: 0.0091
# Epoch 6/50
# 34/34 - 1s - 25ms/step - loss: 1.4055e-04 - val_loss: 0.0086
# Epoch 7/50
# 34/34 - 1s - 26ms/step - loss: 1.4110e-04 - val_loss: 0.0080
# Epoch 8/50
# 34/34 - 1s - 25ms/step - loss: 1.2933e-04 - val_loss: 0.0091
# Epoch 9/50
# 34/34 - 1s - 25ms/step - loss: 1.4798e-04 - val_loss: 0.0077
# Epoch 10/50
# 34/34 - 1s - 26ms/step - loss: 1.2943e-04 - val_loss: 0.0084
# Epoch 11/50
# 34/34 - 1s - 25ms/step - loss: 1.3353e-04 - val_loss: 0.0083
# Epoch 12/50
# 34/34 - 1s - 25ms/step - loss: 1.3421e-04 - val_loss: 0.0073
# Epoch 13/50
# 34/34 - 1s - 25ms/step - loss: 1.2914e-04 - val_loss: 0.0081
# Epoch 14/50
# 34/34 - 1s - 25ms/step - loss: 1.2014e-04 - val_loss: 0.0087
# Epoch 15/50
# 34/34 - 1s - 25ms/step - loss: 1.3933e-04 - val_loss: 0.0064
# Epoch 16/50
# 34/34 - 1s - 24ms/step - loss: 1.1805e-04 - val_loss: 0.0085
# Epoch 17/50
# 34/34 - 1s - 25ms/step - loss: 1.1906e-04 - val_loss: 0.0077
# Epoch 18/50
# 34/34 - 1s - 25ms/step - loss: 1.2644e-04 - val_loss: 0.0067
# Epoch 19/50
# 34/34 - 1s - 25ms/step - loss: 1.1422e-04 - val_loss: 0.0083
# Epoch 20/50
# 34/34 - 1s - 25ms/step - loss: 1.1386e-04 - val_loss: 0.0074
# Epoch 21/50
# 34/34 - 1s - 25ms/step - loss: 1.2354e-04 - val_loss: 0.0065
# Epoch 22/50
# 34/34 - 1s - 27ms/step - loss: 1.1783e-04 - val_loss: 0.0079
# Epoch 23/50
# 34/34 - 1s - 26ms/step - loss: 1.0950e-04 - val_loss: 0.0079
# Epoch 24/50
# 34/34 - 1s - 25ms/step - loss: 1.1974e-04 - val_loss: 0.0062
# Epoch 25/50
# 34/34 - 1s - 25ms/step - loss: 1.2636e-04 - val_loss: 0.0067
# Epoch 26/50
# 34/34 - 1s - 25ms/step - loss: 1.1324e-04 - val_loss: 0.0075
# Epoch 27/50
# 34/34 - 1s - 25ms/step - loss: 1.0718e-04 - val_loss: 0.0075
# Epoch 28/50
# 34/34 - 1s - 28ms/step - loss: 1.0705e-04 - val_loss: 0.0065
# Epoch 29/50
# 34/34 - 1s - 26ms/step - loss: 1.1958e-04 - val_loss: 0.0068
# Epoch 30/50
# 34/34 - 1s - 25ms/step - loss: 1.4941e-04 - val_loss: 0.0063
# Epoch 31/50
# 34/34 - 1s - 26ms/step - loss: 1.1466e-04 - val_loss: 0.0083
# Epoch 32/50
# 34/34 - 1s - 26ms/step - loss: 1.1559e-04 - val_loss: 0.0076
# Epoch 33/50
# 34/34 - 1s - 25ms/step - loss: 1.1663e-04 - val_loss: 0.0071
# Epoch 34/50
# 34/34 - 1s - 26ms/step - loss: 1.0935e-04 - val_loss: 0.0078
# Epoch 35/50
# 34/34 - 1s - 25ms/step - loss: 1.1295e-04 - val_loss: 0.0066
# Epoch 36/50
# 34/34 - 1s - 26ms/step - loss: 1.0728e-04 - val_loss: 0.0070
# Epoch 37/50
# 34/34 - 1s - 27ms/step - loss: 1.0118e-04 - val_loss: 0.0054
# Epoch 38/50
# 34/34 - 1s - 26ms/step - loss: 1.3487e-04 - val_loss: 0.0099
# Epoch 39/50
# 34/34 - 1s - 26ms/step - loss: 1.6140e-04 - val_loss: 0.0061
# Epoch 40/50
# 34/34 - 1s - 27ms/step - loss: 1.1400e-04 - val_loss: 0.0078
# Epoch 41/50
# 34/34 - 1s - 27ms/step - loss: 1.1438e-04 - val_loss: 0.0069
# Epoch 42/50
# 34/34 - 1s - 26ms/step - loss: 1.1518e-04 - val_loss: 0.0069
# Epoch 43/50
# 34/34 - 1s - 27ms/step - loss: 1.0670e-04 - val_loss: 0.0076
# Epoch 44/50
# 34/34 - 1s - 25ms/step - loss: 1.1103e-04 - val_loss: 0.0065
# Epoch 45/50
# 34/34 - 1s - 25ms/step - loss: 1.0659e-04 - val_loss: 0.0069
# Epoch 46/50
# 34/34 - 1s - 25ms/step - loss: 1.0058e-04 - val_loss: 0.0060
# Epoch 47/50
# 34/34 - 1s - 26ms/step - loss: 1.1181e-04 - val_loss: 0.0079
# Epoch 48/50
# 34/34 - 1s - 25ms/step - loss: 1.3372e-04 - val_loss: 0.0063
# Epoch 49/50
# 34/34 - 1s - 25ms/step - loss: 1.1263e-04 - val_loss: 0.0071
# Epoch 50/50
# 34/34 - 1s - 25ms/step - loss: 1.0765e-04 - val_loss: 0.0075
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024010A1E0C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# rmse = 0.0866797619139106
# mae = 0.04549123731096849
# mape = 0.6521096905877404
# r2 = -0.34834381750359067
# var = 0.008698571516063347
#
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 49/49 - 3s - 67ms/step - loss: 0.0018 - val_loss: 0.0193
# Epoch 2/50
# 49/49 - 1s - 24ms/step - loss: 8.0976e-04 - val_loss: 0.0347
# Epoch 3/50
# 49/49 - 1s - 24ms/step - loss: 0.0010 - val_loss: 0.0419
# Epoch 4/50
# 49/49 - 1s - 25ms/step - loss: 0.0011 - val_loss: 0.0396
# Epoch 5/50
# 49/49 - 1s - 24ms/step - loss: 8.4916e-04 - val_loss: 0.0377
# Epoch 6/50
# 49/49 - 1s - 25ms/step - loss: 8.1248e-04 - val_loss: 0.0411
# Epoch 7/50
# 49/49 - 1s - 24ms/step - loss: 7.4102e-04 - val_loss: 0.0504
# Epoch 8/50
# 49/49 - 1s - 25ms/step - loss: 7.7325e-04 - val_loss: 0.0510
# Epoch 9/50
# 49/49 - 1s - 24ms/step - loss: 7.5764e-04 - val_loss: 0.0556
# Epoch 10/50
# 49/49 - 1s - 24ms/step - loss: 7.6441e-04 - val_loss: 0.0537
# Epoch 11/50
# 49/49 - 1s - 25ms/step - loss: 7.4996e-04 - val_loss: 0.0618
# Epoch 12/50
# 49/49 - 1s - 26ms/step - loss: 7.3687e-04 - val_loss: 0.0676
# Epoch 13/50
# 49/49 - 1s - 24ms/step - loss: 7.4576e-04 - val_loss: 0.0732
# Epoch 14/50
# 49/49 - 1s - 25ms/step - loss: 6.9288e-04 - val_loss: 0.0709
# Epoch 45/50
# 49/49 - 1s - 24ms/step - loss: 6.9335e-04 - val_loss: 0.0706
# Epoch 46/50
# 49/49 - 1s - 25ms/step - loss: 6.9300e-04 - val_loss: 0.0677
# Epoch 47/50
# 49/49 - 1s - 25ms/step - loss: 6.9195e-04 - val_loss: 0.0621
# Epoch 48/50
# 49/49 - 1s - 25ms/step - loss: 6.9251e-04 - val_loss: 0.0584
# Epoch 49/50
# 49/49 - 1s - 24ms/step - loss: 6.9370e-04 - val_loss: 0.0625
# Epoch 50/50
# 49/49 - 1s - 24ms/step - loss: 6.8954e-04 - val_loss: 0.0782
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# rmse = 0.27968887736311454
# mae = 0.19564613255215943
# mape = 0.9931957580705089
# r2 = -1.2933810820308307
# var = -0.1762718327189523
#
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 34/34 - 3s - 87ms/step - loss: 0.0015 - val_loss: 0.0141
# Epoch 2/50
# 34/34 - 1s - 25ms/step - loss: 0.0021 - val_loss: 0.0242
# Epoch 3/50
# 34/34 - 1s - 24ms/step - loss: 0.0018 - val_loss: 0.0325
# Epoch 4/50
# 34/34 - 1s - 25ms/step - loss: 0.0019 - val_loss: 0.0162
# Epoch 5/50
# 34/34 - 1s - 24ms/step - loss: 9.8298e-04 - val_loss: 0.0098
# Epoch 6/50
# 34/34 - 1s - 25ms/step - loss: 7.8794e-04 - val_loss: 0.0092
# Epoch 7/50
# 34/34 - 1s - 25ms/step - loss: 7.4222e-04 - val_loss: 0.0095
# Epoch 8/50
# 34/34 - 1s - 25ms/step - loss: 7.5734e-04 - val_loss: 0.0093
# Epoch 9/50
# 34/34 - 1s - 25ms/step - loss: 7.6478e-04 - val_loss: 0.0091
# Epoch 10/50
# 34/34 - 1s - 25ms/step - loss: 7.6038e-04 - val_loss: 0.0089
# Epoch 11/50
# 34/34 - 1s - 25ms/step - loss: 7.4906e-04 - val_loss: 0.0087
# Epoch 12/50
# 34/34 - 1s - 25ms/step - loss: 7.3516e-04 - val_loss: 0.0087
# Epoch 13/50
# 34/34 - 1s - 25ms/step - loss: 7.2380e-04 - val_loss: 0.0087
# Epoch 14/50
# 34/34 - 1s - 26ms/step - loss: 7.1606e-04 - val_loss: 0.0087
# Epoch 15/50
# 34/34 - 1s - 25ms/step - loss: 7.1164e-04 - val_loss: 0.0087
# Epoch 16/50
# 34/34 - 1s - 25ms/step - loss: 7.0840e-04 - val_loss: 0.0087
# Epoch 17/50
# 34/34 - 1s - 25ms/step - loss: 7.0384e-04 - val_loss: 0.0087
# Epoch 18/50
# 34/34 - 1s - 25ms/step - loss: 6.9836e-04 - val_loss: 0.0090
# Epoch 19/50
# 34/34 - 1s - 25ms/step - loss: 6.8381e-04 - val_loss: 0.0093
# Epoch 20/50
# 34/34 - 1s - 25ms/step - loss: 5.9858e-04 - val_loss: 0.0085
# Epoch 21/50
# 34/34 - 1s - 25ms/step - loss: 6.9424e-04 - val_loss: 0.0091
# Epoch 22/50
# 34/34 - 1s - 24ms/step - loss: 6.5340e-04 - val_loss: 0.0093
# Epoch 23/50
# 34/34 - 1s - 25ms/step - loss: 6.3621e-04 - val_loss: 0.0107
# Epoch 24/50
# 34/34 - 1s - 25ms/step - loss: 7.1625e-04 - val_loss: 0.0158
# Epoch 25/50
# 34/34 - 1s - 25ms/step - loss: 7.2726e-04 - val_loss: 0.0125
# Epoch 26/50
# 34/34 - 1s - 25ms/step - loss: 0.0012 - val_loss: 0.0086
# Epoch 27/50
# 34/34 - 1s - 25ms/step - loss: 7.1666e-04 - val_loss: 0.0097
# Epoch 28/50
# 34/34 - 1s - 25ms/step - loss: 7.4389e-04 - val_loss: 0.0087
# Epoch 29/50
# 34/34 - 1s - 25ms/step - loss: 6.8913e-04 - val_loss: 0.0084
# Epoch 30/50
# 34/34 - 1s - 24ms/step - loss: 6.6048e-04 - val_loss: 0.0086
# Epoch 31/50
# 34/34 - 1s - 25ms/step - loss: 6.4275e-04 - val_loss: 0.0088
# Epoch 32/50
# 34/34 - 1s - 25ms/step - loss: 6.3290e-04 - val_loss: 0.0090
# Epoch 33/50
# 34/34 - 1s - 25ms/step - loss: 6.2546e-04 - val_loss: 0.0093
# Epoch 34/50
# 34/34 - 1s - 25ms/step - loss: 6.1759e-04 - val_loss: 0.0096
# Epoch 35/50
# 34/34 - 1s - 25ms/step - loss: 6.0780e-04 - val_loss: 0.0104
# Epoch 36/50
# 34/34 - 1s - 24ms/step - loss: 5.9238e-04 - val_loss: 0.0128
# Epoch 37/50
# 34/34 - 1s - 25ms/step - loss: 5.1809e-04 - val_loss: 0.0198
# Epoch 38/50
# 34/34 - 1s - 25ms/step - loss: 7.1127e-04 - val_loss: 0.0084
# Epoch 39/50
# 34/34 - 1s - 25ms/step - loss: 6.8309e-04 - val_loss: 0.0090
# Epoch 40/50
# 34/34 - 1s - 25ms/step - loss: 6.1821e-04 - val_loss: 0.0090
# Epoch 41/50
# 34/34 - 1s - 25ms/step - loss: 5.9914e-04 - val_loss: 0.0098
# Epoch 42/50
# 34/34 - 1s - 25ms/step - loss: 5.8682e-04 - val_loss: 0.0105
# Epoch 43/50
# 34/34 - 1s - 25ms/step - loss: 5.7386e-04 - val_loss: 0.0111
# Epoch 44/50
# 34/34 - 1s - 25ms/step - loss: 5.6557e-04 - val_loss: 0.0119
# Epoch 45/50
# 34/34 - 1s - 25ms/step - loss: 5.6398e-04 - val_loss: 0.0137
# Epoch 46/50
# 34/34 - 1s - 25ms/step - loss: 6.0973e-04 - val_loss: 0.0128
# Epoch 47/50
# 34/34 - 1s - 25ms/step - loss: 5.7715e-04 - val_loss: 0.0083
# Epoch 48/50
# 34/34 - 1s - 24ms/step - loss: 8.1722e-04 - val_loss: 0.0104
# Epoch 49/50
# 34/34 - 1s - 25ms/step - loss: 7.5546e-04 - val_loss: 0.0083
# Epoch 50/50
# 34/34 - 1s - 26ms/step - loss: 6.6027e-04 - val_loss: 0.0082
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# rmse = 0.09068485483685881
# mae = 0.05892406753117431
# mape = 0.4748858242212981
# r2 = 0.33947743615097414
# var = 0.339486734369171
#
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.15463615107345174
# mae = 0.13131222249167296
# mape = 1.0575201021965746
#
# coinbase
# rmse = 0.3691281011754519
# mae = 0.322120464560239
# mape = 2.331897572647243
#
# huobi
# rmse = 0.0866797619139106
# mae = 0.04549123731096849
# mape = 0.6521096905877404
#
# kraken
# rmse = 0.27968887736311454
# mae = 0.19564613255215943
# mape = 0.9931957580705089
#
# kucoin
# rmse = 0.09068485483685881
# mae = 0.05892406753117431
# mape = 0.4748858242212981
#
# Epoch 1/50
# 17/17 - 2s - 135ms/step - loss: 0.0016 - val_loss: 0.0409
# Epoch 2/50
# 17/17 - 0s - 12ms/step - loss: 0.0023 - val_loss: 0.0184
# Epoch 3/50
# 17/17 - 0s - 11ms/step - loss: 8.0218e-04 - val_loss: 0.0394
# Epoch 4/50
# 17/17 - 0s - 11ms/step - loss: 7.0645e-04 - val_loss: 0.0326
# Epoch 5/50
# 17/17 - 0s - 12ms/step - loss: 5.3450e-04 - val_loss: 0.0267
# Epoch 6/50
# 17/17 - 0s - 11ms/step - loss: 4.6177e-04 - val_loss: 0.0255
# Epoch 7/50
# 17/17 - 0s - 11ms/step - loss: 4.5925e-04 - val_loss: 0.0227
# Epoch 8/50
# 17/17 - 0s - 12ms/step - loss: 4.1253e-04 - val_loss: 0.0214
# Epoch 9/50
# 17/17 - 0s - 11ms/step - loss: 3.9603e-04 - val_loss: 0.0194
# Epoch 10/50
# 17/17 - 0s - 11ms/step - loss: 3.8151e-04 - val_loss: 0.0176
# Epoch 11/50
# 17/17 - 0s - 11ms/step - loss: 3.5825e-04 - val_loss: 0.0163
# Epoch 12/50
# 17/17 - 0s - 11ms/step - loss: 3.3736e-04 - val_loss: 0.0151
# Epoch 13/50
# 17/17 - 0s - 11ms/step - loss: 3.2307e-04 - val_loss: 0.0141
# Epoch 14/50
# 17/17 - 0s - 11ms/step - loss: 3.0948e-04 - val_loss: 0.0134
# Epoch 15/50
# 17/17 - 0s - 11ms/step - loss: 2.9364e-04 - val_loss: 0.0129
# Epoch 16/50
# 17/17 - 0s - 12ms/step - loss: 2.8026e-04 - val_loss: 0.0127
# Epoch 17/50
# 17/17 - 0s - 11ms/step - loss: 2.7208e-04 - val_loss: 0.0126
# Epoch 18/50
# 17/17 - 0s - 12ms/step - loss: 2.6538e-04 - val_loss: 0.0128
# Epoch 19/50
# 17/17 - 0s - 11ms/step - loss: 2.5646e-04 - val_loss: 0.0130
# Epoch 20/50
# 17/17 - 0s - 11ms/step - loss: 2.4792e-04 - val_loss: 0.0134
# Epoch 21/50
# 17/17 - 0s - 11ms/step - loss: 2.4332e-04 - val_loss: 0.0137
# Epoch 22/50
# 17/17 - 0s - 13ms/step - loss: 2.4193e-04 - val_loss: 0.0141
# Epoch 23/50
# 17/17 - 0s - 11ms/step - loss: 2.4058e-04 - val_loss: 0.0146
# Epoch 24/50
# 17/17 - 0s - 13ms/step - loss: 2.3580e-04 - val_loss: 0.0151
)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 2/2 - 2s - 1s/step - loss: 0.0407 - val_loss: 0.0422
# Epoch 2/50
# 2/2 - 0s - 23ms/step - loss: 0.0160 - val_loss: 0.0168
# Epoch 3/50
# 2/2 - 0s - 31ms/step - loss: 0.0121 - val_loss: 0.0147
# Epoch 4/50
# 2/2 - 0s - 31ms/step - loss: 0.0174 - val_loss: 0.0177
# Epoch 5/50
# 2/2 - 0s - 31ms/step - loss: 0.0205 - val_loss: 0.0173
# Epoch 6/50
# 2/2 - 0s - 23ms/step - loss: 0.0190 - val_loss: 0.0150
# Epoch 7/50
# 2/2 - 0s - 31ms/step - loss: 0.0160 - val_loss: 0.0140
# Epoch 8/50
# 2/2 - 0s - 23ms/step - loss: 0.0138 - val_loss: 0.0149
# Epoch 9/50
# 2/2 - 0s - 33ms/step - loss: 0.0131 - val_loss: 0.0167
# Epoch 10/50
# 2/2 - 0s - 29ms/step - loss: 0.0133 - val_loss: 0.0176
# Epoch 11/50
# 2/2 - 0s - 31ms/step - loss: 0.0134 - val_loss: 0.0171
# Epoch 12/50
# 2/2 - 0s - 31ms/step - loss: 0.0129 - val_loss: 0.0156
# Epoch 13/50
# 2/2 - 0s - 23ms/step - loss: 0.0122 - val_loss: 0.0144
# Epoch 14/50
# 2/2 - 0s - 31ms/step - loss: 0.0116 - val_loss: 0.0144
# Epoch 15/50
# 2/2 - 0s - 23ms/step - loss: 0.0114 - val_loss: 0.0154
# Epoch 16/50
# 2/2 - 0s - 31ms/step - loss: 0.0116 - val_loss: 0.0169
# Epoch 17/50
# 2/2 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0180
# Epoch 18/50
# 2/2 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0183
# Epoch 19/50
# 2/2 - 0s - 29ms/step - loss: 0.0116 - val_loss: 0.0179
# Epoch 20/50
# 2/2 - 0s - 24ms/step - loss: 0.0114 - val_loss: 0.0173
# Epoch 21/50
# 2/2 - 0s - 31ms/step - loss: 0.0112 - val_loss: 0.0169
# Epoch 22/50
# 2/2 - 0s - 23ms/step - loss: 0.0111 - val_loss: 0.0169
# Epoch 23/50
# 2/2 - 0s - 31ms/step - loss: 0.0110 - val_loss: 0.0174
# Epoch 24/50
# 2/2 - 0s - 31ms/step - loss: 0.0109 - val_loss: 0.0186
# Epoch 25/50
# 2/2 - 0s - 31ms/step - loss: 0.0108 - val_loss: 0.0204
# Epoch 26/50
# 2/2 - 0s - 23ms/step - loss: 0.0108 - val_loss: 0.0225
# Epoch 27/50
# 2/2 - 0s - 31ms/step - loss: 0.0108 - val_loss: 0.0245
# Epoch 28/50
# 2/2 - 0s - 33ms/step - loss: 0.0108 - val_loss: 0.0259
# Epoch 29/50
# 2/2 - 0s - 27ms/step - loss: 0.0108 - val_loss: 0.0263
# Epoch 30/50
# 2/2 - 0s - 28ms/step - loss: 0.0108 - val_loss: 0.0261
# Epoch 31/50
# 2/2 - 0s - 31ms/step - loss: 0.0107 - val_loss: 0.0257
# Epoch 32/50
# 2/2 - 0s - 31ms/step - loss: 0.0107 - val_loss: 0.0257
# Epoch 33/50
# 2/2 - 0s - 23ms/step - loss: 0.0107 - val_loss: 0.0261
# Epoch 34/50
# 16/16 - 0s - 12ms/step - loss: 4.6790e-04 - val_loss: 0.0091
# Epoch 41/50
# 16/16 - 0s - 12ms/step - loss: 5.9668e-04 - val_loss: 0.0228
# Epoch 42/50
# 16/16 - 0s - 11ms/step - loss: 6.9601e-04 - val_loss: 0.0114
# Epoch 43/50
# 16/16 - 0s - 12ms/step - loss: 5.1790e-04 - val_loss: 0.0091
# Epoch 44/50
# 16/16 - 0s - 12ms/step - loss: 5.3613e-04 - val_loss: 0.0218
# Epoch 45/50
# 16/16 - 0s - 11ms/step - loss: 6.1902e-04 - val_loss: 0.0102
# Epoch 46/50
# 16/16 - 0s - 12ms/step - loss: 5.0023e-04 - val_loss: 0.0111
# Epoch 47/50
# 16/16 - 0s - 13ms/step - loss: 4.3418e-04 - val_loss: 0.0189
# Epoch 48/50
# 16/16 - 0s - 11ms/step - loss: 4.8016e-04 - val_loss: 0.0104
# Epoch 49/50
# 16/16 - 0s - 12ms/step - loss: 4.7307e-04 - val_loss: 0.0166
# Epoch 50/50
# 16/16 - 0s - 12ms/step - loss: 4.2759e-04 - val_loss: 0.0145
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# rmse = 0.1203828093136802
# mae = 0.09664248514702012
# mape = 0.8315596156556909
# r2 = -0.16398419064768355
# var = 0.31188336228462554
#
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.11791301437635553
# mae = 0.09062488447442751
# mape = 0.6776562225701873
#
# coinbase
# rmse = 0.17353391733564075
# mae = 0.1397958516387481
# mape = 1.0983164844459137
#
# huobi
# rmse = 0.08888234832007519
# mae = 0.048813402495919846
# mape = 0.7168558617191098
#
# kraken
# rmse = 0.29595285200669386
# mae = 0.2108454814260352
# mape = 1.2782418853240944
#
# kucoin
# rmse = 0.1203828093136802
# mae = 0.09664248514702012
# mape = 0.8315596156556909
#
# Epoch 1/50
# 24/24 - 2s - 104ms/step - loss: 0.0011 - val_loss: 0.0595
# Epoch 2/50
# 24/24 - 0s - 17ms/step - loss: 0.0026 - val_loss: 0.0273
# Epoch 3/50
# 24/24 - 0s - 18ms/step - loss: 0.0024 - val_loss: 0.0150
# Epoch 4/50
# 24/24 - 0s - 18ms/step - loss: 0.0020 - val_loss: 0.0153
# Epoch 5/50
# 24/24 - 0s - 18ms/step - loss: 7.9283e-04 - val_loss: 0.0151
# Epoch 6/50
# 24/24 - 0s - 18ms/step - loss: 7.6722e-04 - val_loss: 0.0172
# Epoch 7/50
# 24/24 - 0s - 18ms/step - loss: 4.4445e-04 - val_loss: 0.0146
# Epoch 8/50
# 24/24 - 0s - 17ms/step - loss: 4.9708e-04 - val_loss: 0.0144
# Epoch 9/50
# 24/24 - 0s - 17ms/step - loss: 4.3544e-04 - val_loss: 0.0154
# Epoch 10/50
# 24/24 - 0s - 18ms/step - loss: 4.3788e-04 - val_loss: 0.0165
# Epoch 11/50
# 24/24 - 0s - 18ms/step - loss: 3.4065e-04 - val_loss: 0.0163
# Epoch 12/50
# 24/24 - 0s - 18ms/step - loss: 3.3955e-04 - val_loss: 0.0159
# Epoch 13/50
# 24/24 - 0s - 18ms/step - loss: 3.4868e-04 - val_loss: 0.0163
# Epoch 14/50
# 24/24 - 0s - 18ms/step - loss: 3.8998e-04 - val_loss: 0.0179
# Epoch 15/50
# 24/24 - 0s - 17ms/step - loss: 3.8192e-04 - val_loss: 0.0202
# Epoch 16/50
# 24/24 - 0s - 18ms/step - loss: 3.0099e-04 - val_loss: 0.0204
# Epoch 17/50
# 24/24 - 0s - 18ms/step - loss: 3.3642e-04 - val_loss: 0.0185
# Epoch 18/50
# 24/24 - 0s - 18ms/step - loss: 3.5054e-04 - val_loss: 0.0172
# Epoch 19/50
# 24/24 - 0s - 17ms/step - loss: 4.0979e-04 - val_loss: 0.0189
# Epoch 20/50
# 24/24 - 0s - 18ms/step - loss: 6.2610e-04 - val_loss: 0.0253
# Epoch 21/50
# 24/24 - 0s - 18ms/step - loss: 4.5142e-04 - val_loss: 0.0257
# Epoch 22/50
# 24/24 - 0s - 18ms/step - loss: 6.2820e-04 - val_loss: 0.0205
# Epoch 23/50
# 24/24 - 0s - 18ms/step - loss: 8.0065e-04 - val_loss: 0.0169
# Epoch 24/50
# 24/24 - 0s - 18ms/step - loss: 5.6742e-04 - val_loss: 0.0178
# Epoch 25/50
# 24/24 - 0s - 18ms/step - loss: 0.0011 - val_loss: 0.0238
# Epoch 26/50
# 24/24 - 0s - 18ms/step - loss: 4.9459e-04 - val_loss: 0.0194
# Epoch 27/50
# 24/24 - 0s - 17ms/step - loss: 7.6245e-04 - val_loss: 0.0177
# Epoch 28/50
# 24/24 - 0s - 18ms/step - loss: 4.7191e-04 - val_loss: 0.0218
# Epoch 29/50
# 24/24 - 0s - 18ms/step - loss: 6.0589e-04 - val_loss: 0.0246
# Epoch 30/50
# 24/24 - 0s - 18ms/step - loss: 3.4884e-04 - val_loss: 0.0183
# Epoch 31/50
# 24/24 - 0s - 18ms/step - loss: 3.9913e-04 - val_loss: 0.0187
# Epoch 32/50
# 24/24 - 0s - 17ms/step - loss: 3.3167e-04 - val_loss: 0.0238
# Epoch 33/50
# 24/24 - 0s - 18ms/step - loss: 3.8433e-04 - val_loss: 0.0246
# Epoch 34/50
# 24/24 - 0s - 18ms/step - loss: 2.7623e-04 - val_loss: 0.0216
# Epoch 35/50
# 24/24 - 0s - 18ms/step - loss: 2.9480e-04 - val_loss: 0.0239
# Epoch 36/50
# 24/24 - 0s - 17ms/step - loss: 2.9224e-04 - val_loss: 0.0282
# Epoch 37/50
# 24/24 - 0s - 18ms/step - loss: 3.1751e-04 - val_loss: 0.0267
# Epoch 38/50
# 24/24 - 0s - 18ms/step - loss: 2.6224e-04 - val_loss: 0.0259
# Epoch 39/50
# 24/24 - 0s - 18ms/step - loss: 2.7628e-04 - val_loss: 0.0293
# Epoch 40/50
# 24/24 - 0s - 18ms/step - loss: 2.7660e-04 - val_loss: 0.0314
# Epoch 41/50
# 24/24 - 0s - 18ms/step - loss: 2.9090e-04 - val_loss: 0.0288
# Epoch 42/50
# 24/24 - 0s - 17ms/step - loss: 2.5915e-04 - val_loss: 0.0293
# Epoch 43/50
# 24/24 - 0s - 18ms/step - loss: 2.6736e-04 - val_loss: 0.0321
# Epoch 44/50
# 24/24 - 0s - 18ms/step - loss: 2.6415e-04 - val_loss: 0.0326
# Epoch 45/50
# 24/24 - 0s - 18ms/step - loss: 2.7849e-04 - val_loss: 0.0306
# Epoch 46/50
# 24/24 - 0s - 18ms/step - loss: 2.5617e-04 - val_loss: 0.0310
# Epoch 47/50
# 24/24 - 0s - 18ms/step - loss: 2.6058e-04 - val_loss: 0.0328
# Epoch 48/50
# 24/24 - 0s - 17ms/step - loss: 2.5493e-04 - val_loss: 0.0328
# Epoch 49/50
# 24/24 - 0s - 17ms/step - loss: 2.6905e-04 - val_loss: 0.0311
# Epoch 50/50
# 24/24 - 0s - 18ms/step - loss: 2.6317e-04 - val_loss: 0.0311
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# rmse = 0.17633717489168846
# mae = 0.15062794770360913
# mape = 1.2303507378524918
# r2 = -1.1205728283254017
# var = -0.07757218604079519
#
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 3/3 - 2s - 723ms/step - loss: 0.0227 - val_loss: 0.0258
# Epoch 2/50
# 3/3 - 0s - 31ms/step - loss: 0.0179 - val_loss: 0.0374
# Epoch 3/50
# 3/3 - 0s - 31ms/step - loss: 0.0182 - val_loss: 0.0179
# Epoch 4/50
# 3/3 - 0s - 26ms/step - loss: 0.0134 - val_loss: 0.0136
# Epoch 5/50
# 3/3 - 0s - 26ms/step - loss: 0.0139 - val_loss: 0.0136
# Epoch 6/50
# 3/3 - 0s - 31ms/step - loss: 0.0131 - val_loss: 0.0164
# Epoch 7/50
# 3/3 - 0s - 26ms/step - loss: 0.0129 - val_loss: 0.0223
# Epoch 8/50
# 3/3 - 0s - 33ms/step - loss: 0.0141 - val_loss: 0.0233
# Epoch 9/50
# 3/3 - 0s - 26ms/step - loss: 0.0139 - val_loss: 0.0193
# Epoch 10/50
# 3/3 - 0s - 26ms/step - loss: 0.0131 - val_loss: 0.0163
# Epoch 11/50
# 3/3 - 0s - 32ms/step - loss: 0.0128 - val_loss: 0.0159
# Epoch 12/50
# 3/3 - 0s - 26ms/step - loss: 0.0128 - val_loss: 0.0176
# Epoch 13/50
# 3/3 - 0s - 26ms/step - loss: 0.0128 - val_loss: 0.0203
# Epoch 14/50
# 3/3 - 0s - 31ms/step - loss: 0.0130 - val_loss: 0.0216
# Epoch 15/50
# 3/3 - 0s - 25ms/step - loss: 0.0130 - val_loss: 0.0204
# Epoch 16/50
# 3/3 - 0s - 26ms/step - loss: 0.0128 - val_loss: 0.0189
# Epoch 17/50
# 3/3 - 0s - 26ms/step - loss: 0.0127 - val_loss: 0.0187
# Epoch 18/50
# 3/3 - 0s - 33ms/step - loss: 0.0127 - val_loss: 0.0198
# Epoch 19/50
# 3/3 - 0s - 26ms/step - loss: 0.0128 - val_loss: 0.0213
# Epoch 20/50
# 3/3 - 0s - 26ms/step - loss: 0.0128 - val_loss: 0.0216
# Epoch 21/50
# 3/3 - 0s - 31ms/step - loss: 0.0128 - val_loss: 0.0210
# Epoch 22/50
# 3/3 - 0s - 27ms/step - loss: 0.0127 - val_loss: 0.0205
# Epoch 23/50
# 3/3 - 0s - 31ms/step - loss: 0.0127 - val_loss: 0.0208
# Epoch 24/50
# 3/3 - 0s - 25ms/step - loss: 0.0127 - val_loss: 0.0216
# Epoch 25/50
# 3/3 - 0s - 31ms/step - loss: 0.0127 - val_loss: 0.0221
# Epoch 26/50
# 3/3 - 0s - 26ms/step - loss: 0.0127 - val_loss: 0.0219
# Epoch 27/50
# 3/3 - 0s - 26ms/step - loss: 0.0127 - val_loss: 0.0216
# Epoch 28/50
# 3/3 - 0s - 33ms/step - loss: 0.0127 - val_loss: 0.0217
# Epoch 29/50
# 3/3 - 0s - 25ms/step - loss: 0.0127 - val_loss: 0.0222
# Epoch 30/50
# 3/3 - 0s - 28ms/step - loss: 0.0127 - val_loss: 0.0224
# Epoch 31/50
# 3/3 - 0s - 26ms/step - loss: 0.0127 - val_loss: 0.0223
# Epoch 32/50
# 3/3 - 0s - 31ms/step - loss: 0.0127 - val_loss: 0.0223
# Epoch 33/50
# 3/3 - 0s - 31ms/step - loss: 0.0126 - val_loss: 0.0224
# Epoch 34/50
# 3/3 - 0s - 26ms/step - loss: 0.0126 - val_loss: 0.0227
# Epoch 35/50
# 3/3 - 0s - 24ms/step - loss: 0.0126 - val_loss: 0.0228
# Epoch 36/50
# 3/3 - 0s - 27ms/step - loss: 0.0126 - val_loss: 0.0228
# Epoch 37/50
# 3/3 - 0s - 24ms/step - loss: 0.0126 - val_loss: 0.0229
# Epoch 38/50
# 3/3 - 0s - 31ms/step - loss: 0.0126 - val_loss: 0.0231
# Epoch 39/50
# 3/3 - 0s - 26ms/step - loss: 0.0126 - val_loss: 0.0233
# Epoch 40/50
# 3/3 - 0s - 31ms/step - loss: 0.0126 - val_loss: 0.0234
# Epoch 41/50
# 3/3 - 0s - 26ms/step - loss: 0.0126 - val_loss: 0.0235
# Epoch 42/50
# 3/3 - 0s - 26ms/step - loss: 0.0126 - val_loss: 0.0237
# Epoch 43/50
# 3/3 - 0s - 30ms/step - loss: 0.0125 - val_loss: 0.0239
# Epoch 44/50
# 3/3 - 0s - 31ms/step - loss: 0.0125 - val_loss: 0.0241
# Epoch 45/50
# 3/3 - 0s - 26ms/step - loss: 0.0125 - val_loss: 0.0242
# Epoch 46/50
# 3/3 - 0s - 26ms/step - loss: 0.0125 - val_loss: 0.0244
# Epoch 47/50
# 3/3 - 0s - 26ms/step - loss: 0.0125 - val_loss: 0.0247
# Epoch 48/50
# 3/3 - 0s - 31ms/step - loss: 0.0125 - val_loss: 0.0249
# Epoch 49/50
# 3/3 - 0s - 29ms/step - loss: 0.0125 - val_loss: 0.0252
# Epoch 50/50
# 3/3 - 0s - 28ms/step - loss: 0.0125 - val_loss: 0.0254
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# rmse = 0.15948160866023492
# mae = 0.1325549632231974
# mape = 1.022665383274807
# r2 = -0.8864172500179535
# var = -0.09255820733875542
#
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# Epoch 1/50
#
# Epoch 31/50
# 23/23 - 0s - 18ms/step - loss: 1.1466e-04 - val_loss: 0.0073
# Epoch 32/50
# 23/23 - 0s - 18ms/step - loss: 1.1254e-04 - val_loss: 0.0068
# Epoch 33/50
# 23/23 - 0s - 17ms/step - loss: 1.0895e-04 - val_loss: 0.0069
# Epoch 34/50
# 23/23 - 0s - 18ms/step - loss: 1.1188e-04 - val_loss: 0.0064
# Epoch 35/50
# 23/23 - 0s - 18ms/step - loss: 1.1116e-04 - val_loss: 0.0064
# Epoch 36/50
# 23/23 - 0s - 18ms/step - loss: 1.1335e-04 - val_loss: 0.0100
# Epoch 37/50
# 23/23 - 0s - 18ms/step - loss: 1.3074e-04 - val_loss: 0.0056
# Epoch 38/50
# 23/23 - 0s - 17ms/step - loss: 1.1860e-04 - val_loss: 0.0080
# Epoch 39/50
# 23/23 - 0s - 18ms/step - loss: 1.1533e-04 - val_loss: 0.0077
# Epoch 40/50
# 23/23 - 0s - 18ms/step - loss: 1.1338e-04 - val_loss: 0.0074
# Epoch 41/50
# 23/23 - 0s - 17ms/step - loss: 1.0694e-04 - val_loss: 0.0071
# Epoch 42/50
# 23/23 - 0s - 18ms/step - loss: 1.0498e-04 - val_loss: 0.0071
# Epoch 43/50
# 23/23 - 0s - 17ms/step - loss: 1.0397e-04 - val_loss: 0.0069
# Epoch 44/50
# 23/23 - 0s - 17ms/step - loss: 1.0092e-04 - val_loss: 0.0065
# Epoch 45/50
# 23/23 - 0s - 18ms/step - loss: 9.7419e-05 - val_loss: 0.0061
# Epoch 46/50
# 23/23 - 0s - 18ms/step - loss: 9.8085e-05 - val_loss: 0.0059
# Epoch 47/50
# 23/23 - 0s - 18ms/step - loss: 1.0033e-04 - val_loss: 0.0064
# Epoch 48/50
# 23/23 - 1s - 22ms/step - loss: 1.2742e-04 - val_loss: 0.0054
# Epoch 49/50
# 23/23 - 0s - 20ms/step - loss: 1.2425e-04 - val_loss: 0.0075
# Epoch 50/50
# 23/23 - 0s - 20ms/step - loss: 1.0497e-04 - val_loss: 0.0071
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# rmse = 0.08436574242287805
# mae = 0.04151872392127046
# mape = 0.5696234666983263
# r2 = -0.27731347558432895
# var = 0.014470832366205055
#
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# Epoch 1/50
# 33/33 - 3s - 83ms/step - loss: 0.0012 - val_loss: 0.0990
# Epoch 2/50
# 33/33 - 1s - 19ms/step - loss: 0.0011 - val_loss: 0.0721
# Epoch 3/50
# 33/33 - 1s - 18ms/step - loss: 0.0014 - val_loss: 0.0736
# Epoch 4/50
# 33/33 - 1s - 20ms/step - loss: 0.0014 - val_loss: 0.0463
# Epoch 5/50
# 33/33 - 1s - 17ms/step - loss: 8.1525e-04 - val_loss: 0.0415
# Epoch 6/50
# 33/33 - 1s - 17ms/step - loss: 8.4096e-04 - val_loss: 0.0417
# Epoch 7/50
# 33/33 - 1s - 17ms/step - loss: 7.6095e-04 - val_loss: 0.0479
# Epoch 8/50
# 33/33 - 1s - 17ms/step - loss: 7.2979e-04 - val_loss: 0.0510
# Epoch 9/50
# 33/33 - 1s - 17ms/step - loss: 7.3125e-04 - val_loss: 0.0528
# Epoch 10/50
# 33/33 - 1s - 17ms/step - loss: 7.2722e-04 - val_loss: 0.0532
# Epoch 11/50
# 33/33 - 1s - 17ms/step - loss: 7.2531e-04 - val_loss: 0.0546
# Epoch 12/50
# 33/33 - 1s - 17ms/step - loss: 7.2385e-04 - val_loss: 0.0564
# Epoch 13/50
# 33/33 - 1s - 17ms/step - loss: 7.2239e-04 - val_loss: 0.0583
# Epoch 14/50
# 33/33 - 1s - 17ms/step - loss: 7.2107e-04 - val_loss: 0.0602
# Epoch 15/50
# 33/33 - 1s - 17ms/step - loss: 7.2000e-04 - val_loss: 0.0619
# Epoch 16/50
# 33/33 - 1s - 17ms/step - loss: 7.1914e-04 - val_loss: 0.0634
# Epoch 17/50
# 33/33 - 1s - 17ms/step - loss: 7.1840e-04 - val_loss: 0.0647
# Epoch 18/50
# 33/33 - 1s - 17ms/step - loss: 7.1762e-04 - val_loss: 0.0659
# Epoch 19/50
# 33/33 - 1s - 17ms/step - loss: 7.1668e-04 - val_loss: 0.0670
# Epoch 20/50
# 33/33 - 1s - 17ms/step - loss: 7.1552e-04 - val_loss: 0.0681
# Epoch 21/50
# 33/33 - 1s - 18ms/step - loss: 7.1413e-04 - val_loss: 0.0693
# Epoch 22/50
# 33/33 - 1s - 17ms/step - loss: 7.1251e-04 - val_loss: 0.0706
# Epoch 23/50
# 33/33 - 1s - 17ms/step - loss: 7.1070e-04 - val_loss: 0.0721
# Epoch 24/50
# 33/33 - 1s - 17ms/step - loss: 7.0873e-04 - val_loss: 0.0738
# Epoch 25/50
# 33/33 - 1s - 17ms/step - loss: 7.0662e-04 - val_loss: 0.0756
# Epoch 26/50
# 33/33 - 1s - 17ms/step - loss: 7.0441e-04 - val_loss: 0.0775
# Epoch 27/50
# 33/33 - 1s - 18ms/step - loss: 7.0217e-04 - val_loss: 0.0794
# Epoch 28/50
# 33/33 - 1s - 17ms/step - loss: 7.0001e-04 - val_loss: 0.0812
# Epoch 29/50
# 33/33 - 1s - 24ms/step - loss: 6.9811e-04 - val_loss: 0.0827
# Epoch 30/50

# %%
# !pip install sko
# Out:
# Collecting sko
#   Downloading sko-0.5.7-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from sko) (1.26.4)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from sko) (1.11.4)
# Downloading sko-0.5.7-py3-none-any.whl (23 kB)
# Installing collected packages: sko
# Successfully installed sko-0.5.7

# %%
pip show sko
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: sko

# %%
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in d:\anaconda\lib\site-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\lib\site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in d:\anaconda\lib\site-packages (from scikit-optimize) (23.12.0)
# Requirement already satisfied: numpy>=1.20.3 in d:\anaconda\lib\site-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in d:\anaconda\lib\site-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\anaconda\lib\site-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda\lib\site-packages (from scikit-optimize) (23.1)
# Requirement already satisfied: PyYAML in d:\anaconda\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->scikit-optimize) (2.2.0)
