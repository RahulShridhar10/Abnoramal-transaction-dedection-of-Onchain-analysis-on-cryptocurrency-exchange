# %%
import keras
from keras import backend as K
from keras import optimizers
import tensorflow
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

import pandas as pd
import numpy as np
import math
from math import sqrt
import os
import csv
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

from keras import optimizers
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import numpy.linalg as la
import time
import matplotlib.dates as mdates
font1 = {'family': 'Microsoft YaHei',
         'weight': 'normal',
         'size': 13}
plt.style.use('default')
tensorflow.random.set_seed(2)
exchanges = ["binance", "coinbase", "huobi", "kraken", "kucoin"]
beginDates = ['2021-01-30', '2021-11-05', '2020-11-03', '2020-06-25', '2021-02-15']
endDates = ['2021-12-23', '2021-12-24', '2021-09-15', '2021-09-15', '2021-12-24']

li = [] #Save the location of outliers detected using LSTM
li.append([95, 110, 111, 115, 116, 238])
li.append([30])
li.append([153, 190, 241])
li.append([313, 327, 329])
li.append([216, 256, 275, 295])

# class Attention(Layer):
#
#     def __init__(self, units=128, **kwargs):
#         self.units = units
#         super().__init__(**kwargs)
#
#     def __call__(self, inputs):
#         """
#         Many-to-one attention mechanism for Keras.
#         @param inputs: 3D tensor with shape (batch_size, time_steps, input_dim).
#         @return: 2D tensor with shape (batch_size, 128)
#         @author: felixhao28, philipperemy.
#         """
#         hidden_states = inputs
#         hidden_size = int(hidden_states.shape[2])
#         # Inside dense layer
#         #              hidden_states            dot               W            =>           score_first_part
#         # (batch_size, time_steps, hidden_size) dot (hidden_size, hidden_size) => (batch_size, time_steps, hidden_size)
#         # W is the trainable weight matrix of attention Luong's multiplicative style score
#         score_first_part = Dense(hidden_size, use_bias=False, name='attention_score_vec')(hidden_states)
#         #            score_first_part           dot        last_hidden_state     => attention_weights
#         # (batch_size, time_steps, hidden_size) dot   (batch_size, hidden_size)  => (batch_size, time_steps)
#         h_t = Lambda(lambda x: x[:, -1, :], output_shape=(hidden_size,), name='last_hidden_state')(hidden_states)
#         score = Dot(axes=[1, 2], name='attention_score')([h_t, score_first_part])
#         attention_weights = Activation('softmax', name='attention_weight')(score)
#         # (batch_size, time_steps, hidden_size) dot (batch_size, time_steps) => (batch_size, hidden_size)
#         context_vector = Dot(axes=[1, 1], name='context_vector')([hidden_states, attention_weights])
#         pre_activation = Concatenate(name='attention_output')([context_vector, h_t])
#         attention_vector = Dense(self.units, use_bias=False, activation='tanh', name='attention_vector')(pre_activation)
#         return attention_vector
#
#     def get_config(self):
#         return {'units': self.units}
#
#     @classmethod
#     def from_config(cls, config):
#         return cls(**config)

class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")
        super(attention, self).build(input_shape)

    def call(self, x):
        et = tensorflow.squeeze(keras.activations.sigmoid(tf.matmul(x, self.W) + self.b), axis=-1)

        at = at = tf.keras.activations.softmax(et)

        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)


    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()


def model_lstm_att(time_steps, input_dim, n_units, method="LSTM"):
    K.clear_session()  # 清除之前的模型，省得压满内存x
    model_input = Input(shape=(time_steps, input_dim))
    if method == "LSTM":
        x = LSTM(n_units, return_sequences=True)(model_input)
    elif method == "GRU":
        x = GRU(n_units, return_sequences=True)(model_input)
    elif method == "RNN":
        x = SimpleRNN(n_units, return_sequences=True)(model_input)
    x = attention()(x)
    x = Dense(1)(x)
    model = Model(model_input, x)
    return model
def model_lstm(seq_len, n_features, n_units):
    model = Sequential()
    model.add(LSTM(n_units, activation="relu", input_shape=(seq_len, n_features)))
    model.add(Dense(1))
    return model

def evaluation(real, pre):
    rmse = mean_squared_error(real, pre, squared=False)
    mae = mean_absolute_error(real, pre)
    mape = mean_absolute_percentage_error(real, pre)
    r2 = r2_score(real, pre)
    var = 1-(np.var(real - pre))/np.var(real)
    F_norm = la.norm(real-pre)/la.norm(real)

    return rmse, mae, mape, r2, var, 1-F_norm

def min_max_scaler(li):
    min_ = min(li)
    max_ = max(li)
    ret = [(i - min_) / (max_ - min_) for i in li]
    return ret, min_, max_

def data_split(data, train_rate, seq_len, pre_len=1):
    time_len, n_feature = data.shape
    train_size = int(time_len * train_rate)
    train_data = data[0:train_size]
    trainX, trainY, testX, testY = [], [], [], []
    for i in range(train_size-seq_len-pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0: seq_len])
        trainY.append(a[seq_len: seq_len + pre_len, 0])
    for i in range(train_size-seq_len-pre_len, time_len-pre_len-seq_len):
        b = data[i: i+seq_len+pre_len,:]
        testX.append(b[0:seq_len])
        testY.append(b[seq_len:seq_len+pre_len, 0])
    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

def lstm(n_units=64, seq_len=10, batch_size=64, method="LSTM"):
    error_list = []
    rmse_list = []
    mae_list = []
    mape_list = []
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        important = True
        if important:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft.csv')
        else:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft_not_important.csv')
        df = pd.read_csv(file)

        data = df.values
        print("type data dataframe")
        print(type(data))
        time_len, n_features = data.shape
        train_rate = 0.8
        train_size = int(time_len*train_rate)
        trainX, trainY, testX, testY = data_split(data, train_rate=train_rate, seq_len=seq_len)
        scaled_data = data.copy()
        #Normalize the features of each column
        scaler = []
        for j in range(n_features):
            temp_scaler = MinMaxScaler(feature_range=(0, 1))
            temp = temp_scaler.fit_transform(np.array(scaled_data[:, j]).reshape(-1,1))
            scaler.append(temp_scaler)
            temp = temp.reshape(-1)
            scaled_data[:, j] = temp
        trainX1, trainY1, testX1, testY1 = data_split(scaled_data, train_rate=train_rate, seq_len=seq_len)

        #model_name = method+"_attention"
        # print("model_name--------------")
        # print(model_name
        model_name="LSTM"
        if model_name=="LSTM_attention" or model_name=="GRU_attention" or model_name=="RNN_attention":
            model = model_lstm_att(seq_len, n_features, n_units, method=method)
        if model_name=="LSTM":
            model = model_lstm(seq_len, n_features, n_units)

        opt = optimizers.Adam()
        model.compile(optimizer=opt, loss='mse')
        history = model.fit(trainX1, trainY1, epochs=50, batch_size=batch_size, validation_data=(testX1, testY1), verbose=2, shuffle=False)
# Draw historical data
        if True:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(history.history['loss'], label='train')
            plt.plot(history.history['val_loss'], label='test')
            plt.legend()
            plt.title(exchange)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure/lstm_prediction" + exchange + '_' + model_name + '_loss.png')
            plt.show()
        prediction_val = model.predict(testX1)
        print(type(prediction_val))
        print(prediction_val)

        rmse, mae, mape, r2, var, _ = evaluation(testY1, prediction_val)
        print("rmse = {}\nmae = {}\nmape = {}".format(rmse, mae, mape))
        error_list.append("rmse = {}  mae = {} mape = {}\n".format(rmse, mae, mape))

        rmse_list.append(rmse)
        mae_list.append(mae)
        mape_list.append(mape)

        prediction_val = np.array(scaled_data[0:train_size, 0].tolist()+prediction_val[:, 0].tolist())
        prediction_val = prediction_val.reshape(-1,1)
        prediction_val = scaler[0].inverse_transform(prediction_val)
        prediction_val = prediction_val[train_size:,0]
        print("testY")
        testY = testY[:,0]
        print("testY.shape")
        print(testY.shape)
        print(type(testY))
        print("prediction_val")
        print(prediction_val.shape)
        print(type(prediction_val))

        if True:
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")
            # plt.plot(range(time_len-train_size), testY)
            # plt.plot(range(time_len-train_size), np.array(prediction_val))
            upper_bound = [it + 3 * np.std(testY) for it in prediction_val]
            lower_bound = [it - 3 * np.std(testY) for it in prediction_val]

            fig, ax = plt.subplots(figsize=(10, 4),dpi=300)
            beginDate = beginDates[i]
            endDate = endDates[i]

            x = np.arange(mdates.datestr2num(beginDate), mdates.datestr2num(endDate))
            x_range = [np.datetime64(int(c), 'D') for c in x]
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")

            abnormal_x = []
            abnormal_y = []
            for j in range(len(upper_bound)):
                if testY[j] > upper_bound[j]:
                    abnormal_x.append(x_range[j])
                    abnormal_y.append(testY[j])

            miss_x = []
            miss_y = []
            for j in range(len(li[i])):
                if x_range[li[i][j]] not in abnormal_x:
                    miss_x.append(x_range[li[i][j]])
                    miss_y.append(testY[li[i][j]])

            """设置坐标轴的格式"""
            # 设置主刻度, 每6个月一个刻度
            fmt_half_year = mdates.MonthLocator(interval=1)
            ax.xaxis.set_major_locator(fmt_half_year)

            # 设置次刻度，每个月一个刻度
            fmt_month = mdates.MonthLocator()  # 默认即可
            ax.xaxis.set_minor_locator(fmt_month)

            # 设置 x 坐标轴的刻度格式
            ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

            # 设置横坐标轴的范围
            datemin = np.datetime64(x_range[0], 'M')
            # datemax = np.datetime64(x_range[-1], 'Y') + np.timedelta64(1, 'Y')
            datemax = np.datetime64(x_range[-1], 'M') + np.timedelta64(1, 'M')
            ax.set_xlim(datemin, datemax)

            # 设置刻度的显示格式
            ax.format_xdata = mdates.DateFormatter('%Y-%m')
            ax.format_ydata = lambda x: f'$x:.2f$'
            ax.grid(True)
            """自动调整刻度字符串"""
            # 自动调整 x 轴的刻度字符串（旋转）使得每个字符串有足够的空间而不重叠
            fig.autofmt_xdate()

            ax.plot(x_range, testY)
            ax.plot(x_range, np.array(prediction_val))
            ax.plot(x_range, upper_bound, "--")
            ax.plot(x_range, lower_bound, "--")
            ax.scatter(abnormal_x, abnormal_y, c="r", marker="o")
            ax.scatter(miss_x, miss_y, c="dimgrey", marker="o")
            if method=="LSTM":
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected"), loc=2)
            else:
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected", "Anomaly missed"), loc=2)

            plt.title(exchange.title())
            plt.xlabel("time", font1)
            # plt.ylabel("Transaction Amount(USD)")
            plt.ylabel("Trading volume (USD）", font1)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure"+str.lower(method)+'_prediction_' + exchange + '_' + model_name + '_prediction.png')
            plt.show()
    for i in range(len(exchanges)):
        print(exchanges[i])
        print(error_list[i])
    return rmse_list, mae_list, mape_list

def parameter_sensitivity(parameter, para_range):
    rmse_list = [[] for i in range(len(exchanges))] #第一维表示不同交易所，第二位表示不同的参数对应的值
    mae_list = [[] for i in range(len(exchanges))]
    mape_list = [[] for i in range(len(exchanges))]
    for it in para_range:
        if parameter=="Number of hidden units":
            temp_rmse, temp_mae, temp_mape = lstm(n_units=it)
        if parameter=="Sequence length":
            temp_rmse, temp_mae, temp_mape = lstm(seq_len=it)
        if parameter == "Batch size":
            temp_rmse, temp_mae, temp_mape = lstm(batch_size=it)
        for jj in range(len(temp_rmse)):
            rmse_list[jj].append(temp_rmse[jj])
            mae_list[jj].append(temp_mae[jj])
            mape_list[jj].append(temp_mape[jj])
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        rmse_list[i],_,_ = min_max_scaler(rmse_list[i])
        mae_list[i],_,_ = min_max_scaler(mae_list[i])
        mape_list[i],_,_ = min_max_scaler(mape_list[i])
        plt.figure(figsize=(5, 4))

        plt.grid(linestyle="--")
        plt.plot(para_range, rmse_list[i])
        plt.plot(para_range, mae_list[i])
        plt.plot(para_range, mape_list[i])
        if i==0:
            plt.legend(("RMSE", "MAE", "MAPE"), loc='lower right')
        else:
            plt.legend(("RMSE", "MAE", "MAPE"))
        plt.xlabel(parameter)
        plt.ylabel("normalized value",font1)
        plt.title(exchange.title())
        plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure\para_" + parameter + '_' + exchange + '.png')
        plt.show()

def cal_date():
    li = []
    li.append([1400, 1415, 1416, 1420, 1421, 1543])
    li.append([222])
    li.append([1413, 1450, 1501])
    li.append([2097, 2111, 2113])
    li.append([1463, 1503, 1522, 1542])
    start_time = [1499212800, 1619481600, 1495497600, 1438905600, 1505606400]
    for i in range(len(li)):
        print(exchanges[i])
        for j in range(len(li[i])):
            temp_time = start_time[i] + li[i][j]*86400
            timeArray = time.localtime(temp_time)
            otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
            print(otherStyleTime)
if __name__=='__main__':
    rmse_list, mae_list, mape_list=lstm(method="GRU") #method = LSTM, RNN, GRU
    # lstm(106, 6, 74)
    # parameter_sensitivity("Batch size", [16,32,64,128,256,512])
    # parameter_sensitivity("Number of hidden units", [16,32,64,128])
    # parameter_sensitivity("Sequence length", [5,10,20,40,80])
    # cal_date()
# Out:
# type data dataframe
# <class 'numpy.ndarray'>
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 - 3s - 137ms/step - loss: 0.0017 - val_loss: 0.0253
# Epoch 2/50
# 21/21 - 0s - 7ms/step - loss: 5.9087e-04 - val_loss: 0.0181
# Epoch 3/50
# 21/21 - 0s - 7ms/step - loss: 4.6145e-04 - val_loss: 0.0145
# Epoch 4/50
# 21/21 - 0s - 7ms/step - loss: 3.0169e-04 - val_loss: 0.0161
# Epoch 5/50
# 21/21 - 0s - 7ms/step - loss: 3.3909e-04 - val_loss: 0.0143
# Epoch 6/50
# 21/21 - 0s - 7ms/step - loss: 2.6636e-04 - val_loss: 0.0129
# Epoch 7/50
# 21/21 - 0s - 7ms/step - loss: 1.8075e-04 - val_loss: 0.0134
# Epoch 8/50
# 21/21 - 0s - 8ms/step - loss: 2.2215e-04 - val_loss: 0.0128
# Epoch 9/50
# 21/21 - 0s - 8ms/step - loss: 2.2533e-04 - val_loss: 0.0122
# Epoch 10/50
# 21/21 - 0s - 7ms/step - loss: 1.7292e-04 - val_loss: 0.0123
# Epoch 11/50
# 21/21 - 0s - 7ms/step - loss: 2.2354e-04 - val_loss: 0.0121
# Epoch 12/50
# 21/21 - 0s - 8ms/step - loss: 2.3098e-04 - val_loss: 0.0119
# Epoch 13/50
# 21/21 - 0s - 7ms/step - loss: 2.0646e-04 - val_loss: 0.0119
# Epoch 14/50
# 21/21 - 0s - 7ms/step - loss: 2.6683e-04 - val_loss: 0.0119
# Epoch 15/50
# 21/21 - 0s - 7ms/step - loss: 2.4743e-04 - val_loss: 0.0117
# Epoch 16/50
# 21/21 - 0s - 7ms/step - loss: 2.9964e-04 - val_loss: 0.0118
# Epoch 17/50
# 21/21 - 0s - 7ms/step - loss: 3.2602e-04 - val_loss: 0.0119
# Epoch 18/50
# 21/21 - 0s - 7ms/step - loss: 2.6490e-04 - val_loss: 0.0116
# Epoch 19/50
# 21/21 - 0s - 8ms/step - loss: 3.7577e-04 - val_loss: 0.0118
# Epoch 20/50
# 21/21 - 0s - 7ms/step - loss: 3.5974e-04 - val_loss: 0.0119
# Epoch 21/50
# 21/21 - 0s - 7ms/step - loss: 2.3210e-04 - val_loss: 0.0116
# Epoch 22/50
# 21/21 - 0s - 7ms/step - loss: 2.8140e-04 - val_loss: 0.0117
# Epoch 23/50
# 21/21 - 0s - 8ms/step - loss: 2.9335e-04 - val_loss: 0.0115
# Epoch 24/50
# 21/21 - 0s - 7ms/step - loss: 1.8980e-04 - val_loss: 0.0116
# Epoch 25/50
# 21/21 - 0s - 8ms/step - loss: 1.5802e-04 - val_loss: 0.0115
# Epoch 26/50
# 21/21 - 0s - 9ms/step - loss: 1.7777e-04 - val_loss: 0.0115
# Epoch 27/50
# 21/21 - 0s - 8ms/step - loss: 1.6051e-04 - val_loss: 0.0116
# Epoch 28/50
# 21/21 - 0s - 7ms/step - loss: 1.3787e-04 - val_loss: 0.0115
# Epoch 29/50
# 21/21 - 0s - 7ms/step - loss: 1.4288e-04 - val_loss: 0.0116
# Epoch 30/50
# 21/21 - 0s - 8ms/step - loss: 1.4328e-04 - val_loss: 0.0117
# Epoch 31/50
# 21/21 - 0s - 9ms/step - loss: 1.3738e-04 - val_loss: 0.0117
# Epoch 32/50
# 21/21 - 0s - 8ms/step - loss: 1.3753e-04 - val_loss: 0.0118
# Epoch 33/50
# 21/21 - 0s - 8ms/step - loss: 1.3973e-04 - val_loss: 0.0118
# Epoch 34/50
# 21/21 - 0s - 8ms/step - loss: 1.3999e-04 - val_loss: 0.0118
# Epoch 35/50
# 21/21 - 0s - 8ms/step - loss: 1.3669e-04 - val_loss: 0.0119
# Epoch 36/50
# 21/21 - 0s - 8ms/step - loss: 1.3988e-04 - val_loss: 0.0119
# Epoch 37/50
# 21/21 - 0s - 8ms/step - loss: 1.4460e-04 - val_loss: 0.0118
# Epoch 38/50
# 21/21 - 0s - 7ms/step - loss: 1.3811e-04 - val_loss: 0.0119
# Epoch 39/50
# 21/21 - 0s - 8ms/step - loss: 1.4474e-04 - val_loss: 0.0120
# Epoch 40/50
# 21/21 - 0s - 7ms/step - loss: 1.5369e-04 - val_loss: 0.0119
# Epoch 41/50
# 21/21 - 0s - 8ms/step - loss: 1.4035e-04 - val_loss: 0.0120
# Epoch 42/50
# 21/21 - 0s - 7ms/step - loss: 1.4761e-04 - val_loss: 0.0121
# Epoch 43/50
# 21/21 - 0s - 7ms/step - loss: 1.6035e-04 - val_loss: 0.0120
# Epoch 44/50
# 21/21 - 0s - 7ms/step - loss: 1.4065e-04 - val_loss: 0.0121
# Epoch 45/50
# 21/21 - 0s - 8ms/step - loss: 1.4759e-04 - val_loss: 0.0123
# Epoch 46/50
# 21/21 - 0s - 8ms/step - loss: 1.5755e-04 - val_loss: 0.0121
# Epoch 47/50
# 21/21 - 0s - 8ms/step - loss: 1.3674e-04 - val_loss: 0.0121
# Epoch 48/50
# 21/21 - 0s - 8ms/step - loss: 1.4550e-04 - val_loss: 0.0123
# Epoch 49/50
# 21/21 - 0s - 8ms/step - loss: 1.6308e-04 - val_loss: 0.0122
# Epoch 50/50
# 21/21 - 0s - 7ms/step - loss: 1.4226e-04 - val_loss: 0.0122
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# <class 'numpy.ndarray'>
# [[0.12933812]
#  [0.1481148 ]
#  [0.13951793]
#  [0.15083714]
#  [0.16583066]
#  [0.1757991 ]
#  [0.19746324]
#  [0.21581689]
#  [0.22009376]
#  [0.21664508]
#  [0.20347372]
#  [0.21816012]
#  [0.24022068]
#  [0.24613632]
#  [0.22764003]
#  [0.2393876 ]
#  [0.23489334]
#  [0.21311522]
#  [0.2229917 ]
#  [0.21097969]
#  [0.21264598]
#  [0.22607413]
#  [0.21996087]
#  [0.23670135]
#  [0.23541471]
#  [0.25523472]
#  [0.2568558 ]
#  [0.23267753]
#  [0.20281383]
#  [0.17914343]
#  [0.16154383]
#  [0.14836958]
#  [0.1450923 ]
#  [0.1392768 ]
#  [0.1460833 ]
#  [0.14205635]
#  [0.1373629 ]
#  [0.12232267]
#  [0.13063854]
#  [0.13608606]
#  [0.15199994]
#  [0.15622565]
#  [0.1661192 ]
#  [0.17666562]
#  [0.18049364]
#  [0.18201396]
#  [0.2046721 ]
#  [0.20773464]
#  [0.19570738]
#  [0.2019163 ]
#  [0.20700255]
#  [0.19733809]
#  [0.20115718]
#  [0.22366491]
#  [0.21048251]
#  [0.22184786]
#  [0.21366426]
#  [0.19579224]
#  [0.17607048]
#  [0.16945384]
#  [0.17966536]
#  [0.1878606 ]
#  [0.20597248]
#  [0.21435457]
#  [0.22369152]
#  [0.20495069]
#  [0.18842691]
#  [0.20800275]
#  [0.23054963]
#  [0.23548463]
#  [0.2339552 ]
#  [0.22496407]
#  [0.21293196]
#  [0.21151134]
#  [0.23296587]
#  [0.26233724]
#  [0.27077952]
#  [0.24724473]
#  [0.2874077 ]
#  [0.2788498 ]
#  [0.2748051 ]
#  [0.30342492]
#  [0.33467853]
#  [0.3260938 ]
#  [0.3157944 ]
#  [0.2882868 ]
#  [0.23566821]
#  [0.20573327]
#  [0.21458045]
#  [0.2207416 ]
#  [0.236708  ]
#  [0.23862824]
#  [0.24033946]
#  [0.24219675]
#  [0.22657478]
#  [0.26137215]
#  [0.28830725]
#  [0.29355776]
#  [0.30870315]
#  [0.3198163 ]
#  [0.35605028]
#  [0.37537098]
#  [0.42112607]
#  [0.4637397 ]
#  [0.44795862]
#  [0.40852392]
#  [0.38723198]
#  [0.3410171 ]
#  [0.31562525]
#  [0.30987433]
#  [0.29662   ]
#  [0.29065025]
#  [0.29051816]
#  [0.2576127 ]
#  [0.22699594]
#  [0.2327427 ]
#  [0.259305  ]
#  [0.24980289]
#  [0.23165604]
#  [0.22460848]
#  [0.19708125]
#  [0.18311575]
#  [0.16345449]
#  [0.15084618]
#  [0.1455804 ]
#  [0.15788421]
#  [0.17652765]
#  [0.18255836]
#  [0.16251329]
#  [0.14796308]
#  [0.1560506 ]
#  [0.15698057]
#  [0.15876687]
#  [0.15547895]
#  [0.15408996]
#  [0.13828489]
#  [0.13097751]
#  [0.14457531]
#  [0.1507667 ]
#  [0.15469101]
#  [0.18056075]
#  [0.168553  ]
#  [0.14481235]
#  [0.13849516]
#  [0.15108147]
#  [0.1662893 ]
#  [0.14947493]
#  [0.14603433]
#  [0.13744384]
#  [0.12629952]
#  [0.1318016 ]
#  [0.14422573]
#  [0.15185082]
#  [0.15564866]
#  [0.14655465]
#  [0.14940718]
#  [0.13872781]
#  [0.13947684]
#  [0.14149229]
#  [0.17929901]
#  [0.18917486]
#  [0.19833481]
#  [0.18788517]
#  [0.17005217]
#  [0.15474194]
#  [0.16593286]
#  [0.16515064]
#  [0.17865646]
#  [0.17409976]
#  [0.16862354]
#  [0.15096101]
#  [0.13838086]
#  [0.13891016]
#  [0.14185542]
#  [0.14105043]
#  [0.1367175 ]
#  [0.13205865]
#  [0.12972835]
#  [0.12568717]
#  [0.14915472]
#  [0.14953128]
#  [0.16245279]
#  [0.16485393]
#  [0.18048966]
#  [0.18864024]
#  [0.1870774 ]
#  [0.19630292]
#  [0.20871505]
#  [0.2127387 ]
#  [0.1964311 ]
#  [0.2098284 ]
#  [0.20881332]
#  [0.20562854]
#  [0.21557596]
#  [0.21910569]
#  [0.23802096]
#  [0.23079436]
#  [0.21510878]
#  [0.21422489]
#  [0.21834008]
#  [0.23377065]
#  [0.23364073]
#  [0.22658768]
#  [0.23572442]
#  [0.2379445 ]
#  [0.2248928 ]
#  [0.22171384]
#  [0.23662117]
#  [0.24593458]
#  [0.24687953]
#  [0.23462895]
#  [0.2324595 ]
#  [0.21847726]
#  [0.21863773]
#  [0.22967368]
#  [0.23209082]
#  [0.25526825]
#  [0.2633324 ]
#  [0.25662088]
#  [0.25343183]
#  [0.24978648]
#  [0.25902885]
#  [0.29426804]
#  [0.2892164 ]
#  [0.28388768]
#  [0.26173595]
#  [0.2368227 ]
#  [0.21890172]
#  [0.22496323]
#  [0.21155456]
#  [0.22302312]
#  [0.21281219]
#  [0.20244128]
#  [0.1878658 ]
#  [0.17617251]
#  [0.18787196]
#  [0.18453524]
#  [0.18483967]
#  [0.18190695]
#  [0.19790904]
#  [0.16591057]
#  [0.16305973]
#  [0.16882053]
#  [0.16418055]
#  [0.159227  ]
#  [0.15680462]
#  [0.16670224]
#  [0.16232073]
#  [0.159297  ]
#  [0.17152451]
#  [0.19528276]
#  [0.22934616]
#  [0.24490401]
#  [0.23245068]
#  [0.22115216]
#  [0.20287254]
#  [0.21438947]
#  [0.20373859]
#  [0.20963952]
#  [0.21771254]
#  [0.23101446]
#  [0.21727118]
#  [0.20794858]
#  [0.2095869 ]
#  [0.20857501]
#  [0.22498071]
#  [0.2228823 ]
#  [0.2148904 ]
#  [0.20977628]
#  [0.21225792]
#  [0.225615  ]
#  [0.24577633]
#  [0.2676958 ]
#  [0.2942517 ]
#  [0.30659288]
#  [0.31713474]
#  [0.31245616]
#  [0.31212786]
#  [0.32859468]
#  [0.3447498 ]
#  [0.344378  ]
#  [0.346659  ]
#  [0.29976243]
#  [0.28680977]
#  [0.29817063]
#  [0.3165456 ]
#  [0.30919313]
#  [0.31292418]
#  [0.2937273 ]
#  [0.27347276]
#  [0.2637188 ]
#  [0.27173305]
#  [0.27966085]
#  [0.26860994]
#  [0.26380396]
#  [0.24820845]
#  [0.25706077]
#  [0.25436777]
#  [0.24456939]
#  [0.25418815]
#  [0.28314704]
#  [0.2774127 ]
#  [0.2740817 ]
#  [0.25534657]
#  [0.24110028]
#  [0.24702281]
#  [0.26657024]
#  [0.26503575]
#  [0.25683182]
#  [0.25027806]
#  [0.2618456 ]
#  [0.24415877]
#  [0.25299653]
#  [0.24230623]
#  [0.23338293]
#  [0.21757825]
#  [0.21055402]
#  [0.19718221]
#  [0.18652014]
#  [0.18187287]
#  [0.18198067]
#  [0.18433605]
#  [0.18041569]
#  [0.18360883]
#  [0.17006332]
#  [0.16600093]
#  [0.16756845]]
# rmse = 0.11055668290208993
# mae = 0.0787651697935592
# mape = 0.5152234023161364
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# type data dataframe
# <class 'numpy.ndarray'>
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 - 3s - 1s/step - loss: 0.0196 - val_loss: 0.0274
# Epoch 2/50
# 3/3 - 0s - 25ms/step - loss: 0.0157 - val_loss: 0.0396
# Epoch 3/50
# 3/3 - 0s - 25ms/step - loss: 0.0145 - val_loss: 0.0202
# Epoch 4/50
# 3/3 - 0s - 28ms/step - loss: 0.0129 - val_loss: 0.0137
# Epoch 5/50
# 3/3 - 0s - 25ms/step - loss: 0.0138 - val_loss: 0.0134
# Epoch 6/50
# 3/3 - 0s - 22ms/step - loss: 0.0137 - val_loss: 0.0151
# Epoch 7/50
# 3/3 - 0s - 22ms/step - loss: 0.0131 - val_loss: 0.0196
# Epoch 8/50
# 3/3 - 0s - 25ms/step - loss: 0.0130 - val_loss: 0.0209
# Epoch 9/50
# 3/3 - 0s - 29ms/step - loss: 0.0127 - val_loss: 0.0177
# Epoch 10/50
# 3/3 - 0s - 28ms/step - loss: 0.0124 - val_loss: 0.0152
# Epoch 11/50
# 3/3 - 0s - 27ms/step - loss: 0.0126 - val_loss: 0.0150
# Epoch 12/50
# 3/3 - 0s - 25ms/step - loss: 0.0127 - val_loss: 0.0161
# Epoch 13/50
# 3/3 - 0s - 26ms/step - loss: 0.0125 - val_loss: 0.0172
# Epoch 14/50
# 3/3 - 0s - 28ms/step - loss: 0.0125 - val_loss: 0.0166
# Epoch 15/50
# 3/3 - 0s - 24ms/step - loss: 0.0123 - val_loss: 0.0152
# Epoch 16/50
# 3/3 - 0s - 28ms/step - loss: 0.0123 - val_loss: 0.0144
# Epoch 17/50
# 3/3 - 0s - 25ms/step - loss: 0.0124 - val_loss: 0.0144
# Epoch 18/50
# 3/3 - 0s - 26ms/step - loss: 0.0123 - val_loss: 0.0148
# Epoch 19/50
# 3/3 - 0s - 26ms/step - loss: 0.0123 - val_loss: 0.0149
# Epoch 20/50
# 3/3 - 0s - 29ms/step - loss: 0.0122 - val_loss: 0.0145
# Epoch 21/50
# 3/3 - 0s - 28ms/step - loss: 0.0122 - val_loss: 0.0142
# Epoch 22/50
# 3/3 - 0s - 28ms/step - loss: 0.0122 - val_loss: 0.0142
# Epoch 23/50
# 3/3 - 0s - 30ms/step - loss: 0.0122 - val_loss: 0.0143
# Epoch 24/50
# 3/3 - 0s - 28ms/step - loss: 0.0121 - val_loss: 0.0142
# Epoch 25/50
# 3/3 - 0s - 28ms/step - loss: 0.0121 - val_loss: 0.0140
# Epoch 26/50
# 3/3 - 0s - 30ms/step - loss: 0.0121 - val_loss: 0.0139
# Epoch 27/50
# 3/3 - 0s - 27ms/step - loss: 0.0120 - val_loss: 0.0140
# Epoch 28/50
# 3/3 - 0s - 25ms/step - loss: 0.0120 - val_loss: 0.0142
# Epoch 29/50
# 3/3 - 0s - 28ms/step - loss: 0.0119 - val_loss: 0.0141
# Epoch 30/50
# 3/3 - 0s - 25ms/step - loss: 0.0119 - val_loss: 0.0141
# Epoch 31/50
# 3/3 - 0s - 25ms/step - loss: 0.0119 - val_loss: 0.0142
# Epoch 32/50
# 3/3 - 0s - 25ms/step - loss: 0.0118 - val_loss: 0.0144
# Epoch 33/50
# 3/3 - 0s - 25ms/step - loss: 0.0118 - val_loss: 0.0145
# Epoch 34/50
# 3/3 - 0s - 27ms/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 35/50
# 3/3 - 0s - 28ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 36/50
# 3/3 - 0s - 28ms/step - loss: 0.0116 - val_loss: 0.0151
# Epoch 37/50
# 3/3 - 0s - 30ms/step - loss: 0.0116 - val_loss: 0.0153
# Epoch 38/50
# 3/3 - 0s - 28ms/step - loss: 0.0115 - val_loss: 0.0158
# Epoch 39/50
# 3/3 - 0s - 28ms/step - loss: 0.0115 - val_loss: 0.0163
# Epoch 40/50
# 3/3 - 0s - 25ms/step - loss: 0.0114 - val_loss: 0.0168
# Epoch 41/50
# 3/3 - 0s - 28ms/step - loss: 0.0113 - val_loss: 0.0174
# Epoch 42/50
# 3/3 - 0s - 25ms/step - loss: 0.0112 - val_loss: 0.0176
# Epoch 43/50
# 3/3 - 0s - 30ms/step - loss: 0.0112 - val_loss: 0.0184
# Epoch 44/50
# 3/3 - 0s - 25ms/step - loss: 0.0111 - val_loss: 0.0195
# Epoch 45/50
# 3/3 - 0s - 25ms/step - loss: 0.0110 - val_loss: 0.0195
# Epoch 46/50
# 3/3 - 0s - 25ms/step - loss: 0.0109 - val_loss: 0.0210
# Epoch 47/50
# 3/3 - 0s - 28ms/step - loss: 0.0108 - val_loss: 0.0217
# Epoch 48/50
# 3/3 - 0s - 28ms/step - loss: 0.0107 - val_loss: 0.0235
# Epoch 49/50
# 3/3 - 0s - 28ms/step - loss: 0.0106 - val_loss: 0.0237
# Epoch 50/50
# 3/3 - 0s - 28ms/step - loss: 0.0105 - val_loss: 0.0246
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# <class 'numpy.ndarray'>
# [[0.33506423]
#  [0.35200107]
#  [0.39606613]
#  [0.42282334]
#  [0.39115685]
#  [0.39443994]
#  [0.39491284]
#  [0.3789832 ]
#  [0.33909896]
#  [0.3268125 ]
#  [0.32559803]
#  [0.31567004]
#  [0.35146743]
#  [0.39243144]
#  [0.3904862 ]
#  [0.42542067]
#  [0.3649923 ]
#  [0.3358216 ]
#  [0.30969468]
#  [0.3104608 ]
#  [0.31520814]
#  [0.31088656]
#  [0.2585516 ]
#  [0.2763037 ]
#  [0.25694343]
#  [0.24196438]
#  [0.2639402 ]
#  [0.29507196]
#  [0.27307147]
#  [0.23023117]
#  [0.2554337 ]
#  [0.3243963 ]
#  [0.2653901 ]
#  [0.3073073 ]
#  [0.2897699 ]
#  [0.27357405]
#  [0.27214777]
#  [0.28734285]
#  [0.23407556]
#  [0.20167775]
#  [0.21309151]
#  [0.20878153]
#  [0.19592617]
#  [0.20313625]
#  [0.19271466]
#  [0.17181902]
#  [0.16045806]
#  [0.20789672]
#  [0.20832191]]
# rmse = 0.15676515981270583
# mae = 0.1302915850006521
# mape = 0.8694953218740641
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# type data dataframe
# <class 'numpy.ndarray'>
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 - 3s - 140ms/step - loss: 1.5672e-04 - val_loss: 0.0121
# Epoch 2/50
# 20/20 - 0s - 7ms/step - loss: 1.1125e-04 - val_loss: 0.0073
# Epoch 3/50
# 20/20 - 0s - 7ms/step - loss: 1.2025e-04 - val_loss: 0.0064
# Epoch 4/50
# 20/20 - 0s - 7ms/step - loss: 1.2761e-04 - val_loss: 0.0089
# Epoch 5/50
# 20/20 - 0s - 7ms/step - loss: 1.2304e-04 - val_loss: 0.0097
# Epoch 6/50
# 20/20 - 0s - 7ms/step - loss: 1.6182e-04 - val_loss: 0.0052
# Epoch 7/50
# 20/20 - 0s - 7ms/step - loss: 1.6750e-04 - val_loss: 0.0073
# Epoch 8/50
# 20/20 - 0s - 7ms/step - loss: 9.7332e-05 - val_loss: 0.0073
# Epoch 9/50
# 20/20 - 0s - 7ms/step - loss: 8.0647e-05 - val_loss: 0.0067
# Epoch 10/50
# 20/20 - 0s - 7ms/step - loss: 7.5130e-05 - val_loss: 0.0066
# Epoch 11/50
# 20/20 - 0s - 7ms/step - loss: 7.3279e-05 - val_loss: 0.0063
# Epoch 12/50
# 20/20 - 0s - 7ms/step - loss: 7.1777e-05 - val_loss: 0.0062
# Epoch 13/50
# 20/20 - 0s - 7ms/step - loss: 7.0209e-05 - val_loss: 0.0061
# Epoch 14/50
# 20/20 - 0s - 7ms/step - loss: 6.8823e-05 - val_loss: 0.0059
# Epoch 15/50
# 20/20 - 0s - 7ms/step - loss: 6.7530e-05 - val_loss: 0.0058
# Epoch 16/50
# 20/20 - 0s - 7ms/step - loss: 6.6353e-05 - val_loss: 0.0057
# Epoch 17/50
# 20/20 - 0s - 7ms/step - loss: 6.5485e-05 - val_loss: 0.0057
# Epoch 18/50
# 20/20 - 0s - 7ms/step - loss: 6.4578e-05 - val_loss: 0.0056
# Epoch 19/50
# 20/20 - 0s - 7ms/step - loss: 6.3952e-05 - val_loss: 0.0056
# Epoch 20/50
# 20/20 - 0s - 7ms/step - loss: 6.3152e-05 - val_loss: 0.0055
# Epoch 21/50
# 20/20 - 0s - 7ms/step - loss: 6.2675e-05 - val_loss: 0.0055
# Epoch 22/50
# 20/20 - 0s - 7ms/step - loss: 6.2019e-05 - val_loss: 0.0055
# Epoch 23/50
# 20/20 - 0s - 7ms/step - loss: 6.1638e-05 - val_loss: 0.0055
# Epoch 24/50
# 20/20 - 0s - 8ms/step - loss: 6.1028e-05 - val_loss: 0.0055
# Epoch 25/50
# 20/20 - 0s - 7ms/step - loss: 6.0722e-05 - val_loss: 0.0055
# Epoch 26/50
# 20/20 - 0s - 7ms/step - loss: 6.0103e-05 - val_loss: 0.0054
# Epoch 27/50
# 20/20 - 0s - 7ms/step - loss: 5.9772e-05 - val_loss: 0.0055
# Epoch 28/50
# 20/20 - 0s - 7ms/step - loss: 5.9124e-05 - val_loss: 0.0055
# Epoch 29/50
# 20/20 - 0s - 7ms/step - loss: 5.9020e-05 - val_loss: 0.0056
# Epoch 30/50
# 20/20 - 0s - 7ms/step - loss: 5.8202e-05 - val_loss: 0.0054
# Epoch 31/50
# 20/20 - 0s - 7ms/step - loss: 5.8465e-05 - val_loss: 0.0056
# Epoch 32/50
# 20/20 - 0s - 7ms/step - loss: 5.7599e-05 - val_loss: 0.0054
# Epoch 33/50
# 20/20 - 0s - 7ms/step - loss: 5.8809e-05 - val_loss: 0.0058
# Epoch 34/50
# 20/20 - 0s - 7ms/step - loss: 5.8411e-05 - val_loss: 0.0052
# Epoch 35/50
# 20/20 - 0s - 7ms/step - loss: 6.2430e-05 - val_loss: 0.0063
# Epoch 36/50
# 20/20 - 0s - 7ms/step - loss: 6.6040e-05 - val_loss: 0.0050
# Epoch 37/50
# 20/20 - 0s - 7ms/step - loss: 7.8079e-05 - val_loss: 0.0064
# Epoch 38/50
# 20/20 - 0s - 7ms/step - loss: 7.3707e-05 - val_loss: 0.0055
# Epoch 39/50
# 20/20 - 0s - 7ms/step - loss: 6.8566e-05 - val_loss: 0.0056
# Epoch 40/50
# 20/20 - 0s - 7ms/step - loss: 5.9946e-05 - val_loss: 0.0055
# Epoch 41/50
# 20/20 - 0s - 7ms/step - loss: 6.0161e-05 - val_loss: 0.0056
# Epoch 42/50
# 20/20 - 0s - 7ms/step - loss: 5.6382e-05 - val_loss: 0.0056
# Epoch 43/50
# 20/20 - 0s - 7ms/step - loss: 5.5665e-05 - val_loss: 0.0056
# Epoch 44/50
# 20/20 - 0s - 7ms/step - loss: 5.5310e-05 - val_loss: 0.0053
# Epoch 45/50
# 20/20 - 0s - 7ms/step - loss: 5.7144e-05 - val_loss: 0.0057
# Epoch 46/50
# 20/20 - 0s - 7ms/step - loss: 5.4727e-05 - val_loss: 0.0055
# Epoch 47/50
# 20/20 - 0s - 7ms/step - loss: 5.5435e-05 - val_loss: 0.0059
# Epoch 48/50
# 20/20 - 0s - 7ms/step - loss: 5.5479e-05 - val_loss: 0.0053
# Epoch 49/50
# 20/20 - 0s - 7ms/step - loss: 5.7624e-05 - val_loss: 0.0059
# Epoch 50/50
# 20/20 - 0s - 7ms/step - loss: 5.6067e-05 - val_loss: 0.0053
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# <class 'numpy.ndarray'>
# [[0.01378762]
#  [0.01532294]
#  [0.01991016]
#  [0.0186962 ]
#  [0.02247481]
#  [0.0288083 ]
#  [0.02752089]
#  [0.02293182]
#  [0.02178145]
#  [0.02321468]
#  [0.02407358]
#  [0.02480399]
#  [0.02209756]
#  [0.01961338]
#  [0.01809448]
#  [0.01901702]
#  [0.0243006 ]
#  [0.03040513]
#  [0.02577706]
#  [0.03155643]
#  [0.03016217]
#  [0.02839868]
#  [0.02767169]
#  [0.02760928]
#  [0.02459998]
#  [0.02914595]
#  [0.02376555]
#  [0.02072098]
#  [0.01799668]
#  [0.02094097]
#  [0.02237263]
#  [0.01996199]
#  [0.01861462]
#  [0.01730018]
#  [0.01681392]
#  [0.01625991]
#  [0.01540964]
#  [0.01500667]
#  [0.0159273 ]
#  [0.01690834]
#  [0.01728135]
#  [0.01706088]
#  [0.01681443]
#  [0.01632189]
#  [0.01632188]
#  [0.01886988]
#  [0.02672871]
#  [0.0232755 ]
#  [0.02200352]
#  [0.01919606]
#  [0.01909793]
#  [0.0193299 ]
#  [0.01789282]
#  [0.01899994]
#  [0.01969167]
#  [0.01860903]
#  [0.02393686]
#  [0.02689782]
#  [0.02488119]
#  [0.02640433]
#  [0.02623688]
#  [0.02341826]
#  [0.0248551 ]
#  [0.03741627]
#  [0.05808113]
#  [0.0438704 ]
#  [0.03843151]
#  [0.03683137]
#  [0.04667946]
#  [0.04202042]
#  [0.04043135]
#  [0.05441725]
#  [0.04431503]
#  [0.03912149]
#  [0.03815115]
#  [0.03735057]
#  [0.03757172]
#  [0.03133534]
#  [0.03018415]
#  [0.04034808]
#  [0.03948665]
#  [0.0389553 ]
#  [0.04354694]
#  [0.03842435]
#  [0.03942741]
#  [0.04336408]
#  [0.04219528]
#  [0.04170221]
#  [0.03903136]
#  [0.04425016]
#  [0.04080461]
#  [0.03877714]
#  [0.03953212]
#  [0.05255106]
#  [0.05514267]
#  [0.05683402]
#  [0.05930549]
#  [0.05551396]
#  [0.05028055]
#  [0.05213753]
#  [0.05546201]
#  [0.0577874 ]
#  [0.05328982]
#  [0.04866049]
#  [0.04741665]
#  [0.04744559]
#  [0.0493148 ]
#  [0.04710136]
#  [0.04579211]
#  [0.04894279]
#  [0.0497645 ]
#  [0.05391968]
#  [0.04855959]
#  [0.05497688]
#  [0.06864103]
#  [0.06113297]
#  [0.05578021]
#  [0.05315638]
#  [0.04615914]
#  [0.04564607]
#  [0.0424225 ]
#  [0.04186412]
#  [0.03974015]
#  [0.03777397]
#  [0.03695798]
#  [0.03782668]
#  [0.04155312]
#  [0.04642602]
#  [0.04852773]
#  [0.04790781]
#  [0.04792665]
#  [0.05067347]
#  [0.05277435]
#  [0.04892952]
#  [0.05341623]
#  [0.05720593]
#  [0.05657064]
#  [0.05705902]
#  [0.05420886]
#  [0.05093355]
#  [0.04580001]
#  [0.04826329]
#  [0.04795172]
#  [0.04824725]
#  [0.05043603]
#  [0.04954898]
#  [0.05005245]
#  [0.04344505]
#  [0.04862275]
#  [0.05429941]
#  [0.06406505]
#  [0.07218307]
#  [0.07531405]
#  [0.07315082]
#  [0.07872783]
#  [0.06774282]
#  [0.0636354 ]
#  [0.05918013]
#  [0.06044619]
#  [0.05895368]
#  [0.0549449 ]
#  [0.04854004]
#  [0.04987684]
#  [0.05549055]
#  [0.05923741]
#  [0.05287293]
#  [0.05718264]
#  [0.05893544]
#  [0.06524306]
#  [0.06675921]
#  [0.07465432]
#  [0.07879929]
#  [0.07669675]
#  [0.07614938]
#  [0.06462532]
#  [0.05749889]
#  [0.05128448]
#  [0.0476715 ]
#  [0.04776521]
#  [0.04476478]
#  [0.0408303 ]
#  [0.03926266]
#  [0.03479007]
#  [0.04013736]
#  [0.04440625]
#  [0.04358833]
#  [0.04358898]
#  [0.04300477]
#  [0.04800113]
#  [0.0580739 ]
#  [0.06960727]
#  [0.12106972]
#  [0.09899459]
#  [0.09453794]
#  [0.08639538]
#  [0.07300868]
#  [0.06145898]
#  [0.06805096]
#  [0.0634886 ]
#  [0.08075427]
#  [0.09476478]
#  [0.08467409]
#  [0.07347868]
#  [0.07062791]
#  [0.06613038]
#  [0.0628942 ]
#  [0.05618383]
#  [0.04724906]
#  [0.04379294]
#  [0.04191627]
#  [0.03952395]
#  [0.03869376]
#  [0.03572278]
#  [0.03259499]
#  [0.03275545]
#  [0.0354038 ]
#  [0.035364  ]
#  [0.03158862]
#  [0.03306907]
#  [0.03614925]
#  [0.03432447]
#  [0.03100497]
#  [0.02825245]
#  [0.02564748]
#  [0.02572395]
#  [0.02562007]
#  [0.02557106]
#  [0.02457016]
#  [0.0234753 ]
#  [0.02383345]
#  [0.02119238]
#  [0.02043543]
#  [0.02675921]
#  [0.03908766]
#  [0.03580076]
#  [0.03043683]
#  [0.03448815]
#  [0.02893184]
#  [0.02758078]
#  [0.02792963]
#  [0.02513264]
#  [0.02478155]
#  [0.06425336]
#  [0.05055558]
#  [0.04438717]
#  [0.03999314]
#  [0.03764468]
#  [0.04019984]
#  [0.0362671 ]
#  [0.0386733 ]
#  [0.03874893]
#  [0.03483497]
#  [0.02773696]
#  [0.02580215]
#  [0.02520755]
#  [0.02424494]
#  [0.0243683 ]
#  [0.02367477]
#  [0.02219925]
#  [0.02221911]
#  [0.02392532]
#  [0.0252578 ]
#  [0.02691006]
#  [0.02640961]
#  [0.02509381]
#  [0.02632599]
#  [0.0227524 ]
#  [0.03239786]
#  [0.03156404]
#  [0.02925393]
#  [0.02899958]
#  [0.02648367]
#  [0.02328381]
#  [0.02602121]
#  [0.02767414]
#  [0.02819668]
#  [0.0303257 ]
#  [0.03414826]
#  [0.03580783]
#  [0.03407014]
#  [0.03221972]
#  [0.0426043 ]
#  [0.03602251]
#  [0.03392968]
#  [0.03310781]
#  [0.03184256]
#  [0.02829785]
#  [0.03057685]
#  [0.03803357]
#  [0.03630528]
#  [0.03392074]
#  [0.02918947]
#  [0.0280413 ]
#  [0.02440378]
#  [0.02679335]
#  [0.02910529]
#  [0.0312223 ]
#  [0.0293121 ]
#  [0.031535  ]
#  [0.0304747 ]
#  [0.0299793 ]
#  [0.02775837]
#  [0.03386842]
#  [0.04098496]
#  [0.04213594]
#  [0.04389322]
#  [0.0507134 ]
#  [0.05167035]
#  [0.04402366]
#  [0.04376266]
#  [0.04962792]
#  [0.04959887]
#  [0.04390041]
#  [0.04172713]
#  [0.03573571]
#  [0.03105394]]
# rmse = 0.07288621602264281
# mae = 0.02540074173293107
# mape = 0.34285848164275673
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# type data dataframe
# <class 'numpy.ndarray'>
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 - 3s - 96ms/step - loss: 0.0014 - val_loss: 0.0302
# Epoch 2/50
# 28/28 - 0s - 6ms/step - loss: 6.6868e-04 - val_loss: 0.0366
# Epoch 3/50
# 28/28 - 0s - 6ms/step - loss: 7.9904e-04 - val_loss: 0.0491
# Epoch 4/50
# 28/28 - 0s - 6ms/step - loss: 7.7616e-04 - val_loss: 0.0251
# Epoch 5/50
# 28/28 - 0s - 7ms/step - loss: 5.3431e-04 - val_loss: 0.0258
# Epoch 6/50
# 28/28 - 0s - 7ms/step - loss: 5.8339e-04 - val_loss: 0.0332
# Epoch 7/50
# 28/28 - 0s - 7ms/step - loss: 5.2113e-04 - val_loss: 0.0259
# Epoch 8/50
# 28/28 - 0s - 6ms/step - loss: 5.0734e-04 - val_loss: 0.0225
# Epoch 9/50
# 28/28 - 1s - 23ms/step - loss: 5.1948e-04 - val_loss: 0.0282
# Epoch 10/50
# 28/28 - 0s - 6ms/step - loss: 5.0471e-04 - val_loss: 0.0226
# Epoch 11/50
# 28/28 - 0s - 6ms/step - loss: 5.0104e-04 - val_loss: 0.0259
# Epoch 12/50
# 28/28 - 0s - 7ms/step - loss: 4.9673e-04 - val_loss: 0.0267
# Epoch 13/50
# 28/28 - 0s - 7ms/step - loss: 4.9416e-04 - val_loss: 0.0248
# Epoch 14/50
# 28/28 - 0s - 7ms/step - loss: 4.9258e-04 - val_loss: 0.0254
# Epoch 15/50
# 28/28 - 0s - 7ms/step - loss: 4.8989e-04 - val_loss: 0.0242
# Epoch 16/50
# 28/28 - 0s - 7ms/step - loss: 4.8794e-04 - val_loss: 0.0250
# Epoch 17/50
# 28/28 - 0s - 8ms/step - loss: 4.8924e-04 - val_loss: 0.0231
# Epoch 18/50
# 28/28 - 0s - 8ms/step - loss: 4.8581e-04 - val_loss: 0.0271
# Epoch 19/50
# 28/28 - 0s - 8ms/step - loss: 4.9542e-04 - val_loss: 0.0202
# Epoch 20/50
# 28/28 - 0s - 7ms/step - loss: 4.9230e-04 - val_loss: 0.0274
# Epoch 21/50
# 28/28 - 0s - 8ms/step - loss: 5.2678e-04 - val_loss: 0.0182
# Epoch 22/50
# 28/28 - 0s - 7ms/step - loss: 5.4501e-04 - val_loss: 0.0358
# Epoch 23/50
# 28/28 - 0s - 7ms/step - loss: 5.6599e-04 - val_loss: 0.0295
# Epoch 24/50
# 28/28 - 0s - 7ms/step - loss: 5.0766e-04 - val_loss: 0.0315
# Epoch 25/50
# 28/28 - 0s - 8ms/step - loss: 4.9425e-04 - val_loss: 0.0232
# Epoch 26/50
# 28/28 - 0s - 8ms/step - loss: 4.8258e-04 - val_loss: 0.0231
# Epoch 27/50
# 28/28 - 0s - 7ms/step - loss: 4.8001e-04 - val_loss: 0.0240
# Epoch 28/50
# 28/28 - 0s - 7ms/step - loss: 4.7724e-04 - val_loss: 0.0241
# Epoch 29/50
# 28/28 - 0s - 7ms/step - loss: 4.7516e-04 - val_loss: 0.0243
# Epoch 30/50
# 28/28 - 0s - 7ms/step - loss: 4.7432e-04 - val_loss: 0.0233
# Epoch 31/50
# 28/28 - 0s - 7ms/step - loss: 4.7261e-04 - val_loss: 0.0250
# Epoch 32/50
# 28/28 - 0s - 7ms/step - loss: 4.7701e-04 - val_loss: 0.0211
# Epoch 33/50
# 28/28 - 0s - 7ms/step - loss: 4.8080e-04 - val_loss: 0.0307
# Epoch 34/50
# 28/28 - 0s - 7ms/step - loss: 5.3883e-04 - val_loss: 0.0171
# Epoch 35/50
# 28/28 - 0s - 7ms/step - loss: 5.4914e-04 - val_loss: 0.0314
# Epoch 36/50
# 28/28 - 0s - 7ms/step - loss: 5.7232e-04 - val_loss: 0.0250
# Epoch 37/50
# 28/28 - 0s - 7ms/step - loss: 4.9629e-04 - val_loss: 0.0245
# Epoch 38/50
# 28/28 - 0s - 7ms/step - loss: 5.0248e-04 - val_loss: 0.0268
# Epoch 39/50
# 28/28 - 0s - 7ms/step - loss: 4.7918e-04 - val_loss: 0.0259
# Epoch 40/50
# 28/28 - 0s - 7ms/step - loss: 4.8030e-04 - val_loss: 0.0253
# Epoch 41/50
# 28/28 - 0s - 7ms/step - loss: 4.7198e-04 - val_loss: 0.0259
# Epoch 42/50
# 28/28 - 0s - 7ms/step - loss: 4.6761e-04 - val_loss: 0.0252
# Epoch 43/50
# 28/28 - 0s - 7ms/step - loss: 4.6457e-04 - val_loss: 0.0303
# Epoch 44/50
# 28/28 - 0s - 7ms/step - loss: 4.6438e-04 - val_loss: 0.0246
# Epoch 45/50
# 28/28 - 0s - 7ms/step - loss: 4.6382e-04 - val_loss: 0.0356
# Epoch 46/50
# 28/28 - 0s - 7ms/step - loss: 4.8566e-04 - val_loss: 0.0226
# Epoch 47/50
# 28/28 - 0s - 7ms/step - loss: 4.9515e-04 - val_loss: 0.0480
# Epoch 48/50
# 28/28 - 0s - 6ms/step - loss: 5.8558e-04 - val_loss: 0.0224
# Epoch 49/50
# 28/28 - 0s - 7ms/step - loss: 5.3102e-04 - val_loss: 0.0260
# Epoch 50/50
# 28/28 - 0s - 7ms/step - loss: 4.9550e-04 - val_loss: 0.0279
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# <class 'numpy.ndarray'>
# [[0.02033466]
#  [0.0208205 ]
#  [0.02050469]
#  [0.02016929]
#  [0.01958038]
#  [0.01906428]
#  [0.01977274]
#  [0.02112667]
#  [0.02133537]
#  [0.02137038]
#  [0.02096561]
#  [0.02016734]
#  [0.01918177]
#  [0.02005958]
#  [0.02129613]
#  [0.02262191]
#  [0.02214523]
#  [0.02104321]
#  [0.02057639]
#  [0.0198262 ]
#  [0.02023952]
#  [0.01987099]
#  [0.01927391]
#  [0.01858882]
#  [0.01874918]
#  [0.01797507]
#  [0.01818791]
#  [0.0190052 ]
#  [0.02017554]
#  [0.0212821 ]
#  [0.02443614]
#  [0.02630964]
#  [0.02725914]
#  [0.02834972]
#  [0.03264076]
#  [0.03313927]
#  [0.03192876]
#  [0.03158672]
#  [0.03209945]
#  [0.03196419]
#  [0.03289263]
#  [0.03356048]
#  [0.03243147]
#  [0.03227358]
#  [0.03194733]
#  [0.03259344]
#  [0.03127997]
#  [0.02998973]
#  [0.02998557]
#  [0.03059249]
#  [0.03542014]
#  [0.04227286]
#  [0.04972372]
#  [0.04496723]
#  [0.04113018]
#  [0.04258413]
#  [0.04670321]
#  [0.04489048]
#  [0.04214603]
#  [0.04383885]
#  [0.0446292 ]
#  [0.03853103]
#  [0.03833585]
#  [0.03876923]
#  [0.03822057]
#  [0.03581016]
#  [0.03533239]
#  [0.03328792]
#  [0.03787348]
#  [0.04524269]
#  [0.06842727]
#  [0.08217219]
#  [0.08759855]
#  [0.08294798]
#  [0.08029455]
#  [0.06898178]
#  [0.05938944]
#  [0.05343751]
#  [0.04727384]
#  [0.04514953]
#  [0.04024617]
#  [0.03493376]
#  [0.03309811]
#  [0.03652481]
#  [0.03743711]
#  [0.03604909]
#  [0.055796  ]
#  [0.06036087]
#  [0.05383625]
#  [0.04696212]
#  [0.04541749]
#  [0.04224243]
#  [0.03887032]
#  [0.03518023]
#  [0.03218256]
#  [0.02917222]
#  [0.02706452]
#  [0.02667322]
#  [0.02832064]
#  [0.02780256]
#  [0.02669728]
#  [0.02619853]
#  [0.02375682]
#  [0.02374662]
#  [0.02350751]
#  [0.02454358]
#  [0.02417994]
#  [0.02304236]
#  [0.02235362]
#  [0.02154345]
#  [0.02135712]
#  [0.02295666]
#  [0.02178382]
#  [0.02294262]
#  [0.02264497]
#  [0.02324245]
#  [0.02198599]
#  [0.02118049]
#  [0.02057998]
#  [0.02072125]
#  [0.02290949]
#  [0.02368431]
#  [0.02228784]
#  [0.02026453]
#  [0.02026201]
#  [0.02064896]
#  [0.02083381]
#  [0.02128498]
#  [0.02039443]
#  [0.02109643]
#  [0.01999889]
#  [0.02065262]
#  [0.02162062]
#  [0.02073495]
#  [0.02045999]
#  [0.02242314]
#  [0.02775877]
#  [0.02743586]
#  [0.02792002]
#  [0.02695589]
#  [0.0254401 ]
#  [0.02550025]
#  [0.02612244]
#  [0.02797037]
#  [0.02579085]
#  [0.02590618]
#  [0.02628527]
#  [0.02771821]
#  [0.03128299]
#  [0.03236551]
#  [0.03135099]
#  [0.03513742]
#  [0.03935792]
#  [0.04394194]
#  [0.04859421]
#  [0.04559778]
#  [0.04690904]
#  [0.04432867]
#  [0.04020148]
#  [0.0374813 ]
#  [0.03967553]
#  [0.04188782]
#  [0.03524803]
#  [0.03229733]
#  [0.03652321]
#  [0.0356904 ]
#  [0.03808072]
#  [0.03650795]
#  [0.03822006]
#  [0.03938196]
#  [0.03774062]
#  [0.03632003]
#  [0.0347763 ]
#  [0.03683422]
#  [0.0340014 ]
#  [0.03589125]
#  [0.03934364]
#  [0.05543698]
#  [0.05027991]
#  [0.04460004]
#  [0.04334071]
#  [0.04328873]
#  [0.04116698]
#  [0.04198702]
#  [0.03908293]
#  [0.03678999]
#  [0.03695395]
#  [0.04695141]
#  [0.05904184]
#  [0.05947616]
#  [0.06145237]
#  [0.06035393]
#  [0.05556539]
#  [0.06272644]
#  [0.11182581]
#  [0.17103729]
#  [0.16485746]
#  [0.16568865]
#  [0.17563772]
#  [0.1728612 ]
#  [0.15287119]
#  [0.14365087]
#  [0.16032256]
#  [0.1362981 ]
#  [0.11129987]
#  [0.10122362]
#  [0.09318778]
#  [0.088816  ]
#  [0.08048059]
#  [0.07695221]
#  [0.09925683]
#  [0.10233606]
#  [0.09864233]
#  [0.09847774]
#  [0.08793357]
#  [0.09154139]
#  [0.09885685]
#  [0.09138776]
#  [0.07913665]
#  [0.07559931]
#  [0.08261946]
#  [0.09063578]
#  [0.09758807]
#  [0.09977022]
#  [0.12149103]
#  [0.14243601]
#  [0.16821042]
#  [0.20155007]
#  [0.20224407]
#  [0.19882299]
#  [0.20863163]
#  [0.22220877]
#  [0.2222882 ]
#  [0.21385716]
#  [0.2050038 ]
#  [0.18950088]
#  [0.1668365 ]
#  [0.1629533 ]
#  [0.15739827]
#  [0.15824206]
#  [0.16493477]
#  [0.16925862]
#  [0.19238345]
#  [0.17978387]
#  [0.20369393]
#  [0.24554399]
#  [0.22068578]
#  [0.18979967]
#  [0.16843145]
#  [0.14688787]
#  [0.13012691]
#  [0.120181  ]
#  [0.1080562 ]
#  [0.09763265]
#  [0.08870794]
#  [0.08266257]
#  [0.08210719]
#  [0.08801252]
#  [0.09908467]
#  [0.1029232 ]
#  [0.10585279]
#  [0.11188906]
#  [0.11797018]
#  [0.1313218 ]
#  [0.1291353 ]
#  [0.13351461]
#  [0.1362923 ]
#  [0.13768281]
#  [0.13679269]
#  [0.12626466]
#  [0.12258132]
#  [0.1204637 ]
#  [0.12238885]
#  [0.11609068]
#  [0.10840254]
#  [0.10691034]
#  [0.10266469]
#  [0.09984533]
#  [0.09995869]
#  [0.10764404]
#  [0.11286911]
#  [0.12692937]
#  [0.1353961 ]
#  [0.14905332]
#  [0.14720832]
#  [0.13953845]
#  [0.14068048]
#  [0.13502131]
#  [0.12842757]
#  [0.11880708]
#  [0.10877486]
#  [0.10605028]
#  [0.10287818]
#  [0.10045493]
#  [0.11066023]
#  [0.1185142 ]
#  [0.11719169]
#  [0.14360061]
#  [0.14427702]
#  [0.15880421]
#  [0.16676837]
#  [0.19171287]
#  [0.17820162]
#  [0.17976342]
#  [0.1656097 ]
#  [0.14029247]
#  [0.12838942]
#  [0.11660682]
#  [0.11379131]
#  [0.1186597 ]
#  [0.11997184]
#  [0.11442669]
#  [0.12129438]
#  [0.12499252]
#  [0.16618228]
#  [0.17811872]
#  [0.168298  ]
#  [0.16430682]
#  [0.15734379]
#  [0.18852264]
#  [0.21006073]
#  [0.28204596]
#  [0.31965706]
#  [0.33547896]
#  [0.345414  ]
#  [0.32912424]
#  [0.2988844 ]
#  [0.28001451]
#  [0.2595746 ]
#  [0.23393513]
#  [0.27527308]
#  [0.2476431 ]
#  [0.2061732 ]
#  [0.16958909]
#  [0.16312514]
#  [0.14816889]
#  [0.12759203]
#  [0.11240508]
#  [0.10354878]
#  [0.09054415]
#  [0.08407852]
#  [0.08619049]
#  [0.08577982]
#  [0.08083673]
#  [0.07896242]
#  [0.08256344]
#  [0.08197636]
#  [0.08378753]
#  [0.08387332]
#  [0.08503479]
#  [0.08209316]
#  [0.07991555]
#  [0.07788592]
#  [0.07748715]
#  [0.07675698]
#  [0.07791551]
#  [0.07992669]
#  [0.07918826]
#  [0.07680571]
#  [0.07537752]
#  [0.07597271]
#  [0.07363509]
#  [0.07360999]
#  [0.07203641]
#  [0.07937239]
#  [0.07050729]
#  [0.06719944]
#  [0.06515095]
#  [0.06313971]
#  [0.06571802]
#  [0.07578526]
#  [0.07292776]
#  [0.07323478]
#  [0.07254106]
#  [0.07216305]
#  [0.07081988]
#  [0.07072659]
#  [0.0707601 ]
#  [0.07542074]
#  [0.07778625]
#  [0.07825459]
#  [0.07987635]
#  [0.07642028]
#  [0.07249661]
#  [0.07240339]
#  [0.07241403]
#  [0.07222047]
#  [0.07164424]
#  [0.0697455 ]
#  [0.06593607]
#  [0.06323516]
#  [0.06241288]
#  [0.06110854]
#  [0.06129119]
#  [0.06255123]
#  [0.06378281]
#  [0.06456438]
#  [0.06438006]
#  [0.07321337]
#  [0.08142825]
#  [0.08400974]
#  [0.08347926]
#  [0.08480066]
#  [0.08608416]
#  [0.08842432]
#  [0.09106904]
#  [0.09129182]
#  [0.09422381]
#  [0.09943143]
#  [0.10358488]
#  [0.10999461]
#  [0.11299884]
#  [0.11841632]
#  [0.1196444 ]
#  [0.12119043]
#  [0.12161359]
#  [0.1245382 ]
#  [0.12019844]
#  [0.11598565]
#  [0.12006901]
#  [0.11703472]
#  [0.11543001]
#  [0.1162644 ]
#  [0.11990932]
#  [0.11782455]
#  [0.11599597]
#  [0.12447143]
#  [0.12754042]
#  [0.12971143]
#  [0.13044254]
#  [0.1335355 ]
#  [0.12878448]
#  [0.12602812]
#  [0.13345228]
#  [0.14196177]
#  [0.15725867]
#  [0.16720007]
#  [0.17940454]
#  [0.1721694 ]
#  [0.17024375]
#  [0.17627825]
#  [0.18188779]
#  [0.17957138]
#  [0.17828089]
#  [0.1699592 ]
#  [0.15705886]
#  [0.14860843]]
# rmse = 0.16714118293107924
# mae = 0.09931252662788892
# mape = 0.5258761375786698
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# type data dataframe
# <class 'numpy.ndarray'>
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 - 3s - 155ms/step - loss: 5.7580e-04 - val_loss: 0.0102
# Epoch 2/50
# 20/20 - 0s - 7ms/step - loss: 3.4753e-04 - val_loss: 0.0070
# Epoch 3/50
# 20/20 - 0s - 7ms/step - loss: 2.6533e-04 - val_loss: 0.0063
# Epoch 4/50
# 20/20 - 0s - 7ms/step - loss: 2.3404e-04 - val_loss: 0.0061
# Epoch 5/50
# 20/20 - 0s - 7ms/step - loss: 2.2100e-04 - val_loss: 0.0065
# Epoch 6/50
# 20/20 - 0s - 7ms/step - loss: 2.1223e-04 - val_loss: 0.0074
# Epoch 7/50
# 20/20 - 0s - 7ms/step - loss: 2.3210e-04 - val_loss: 0.0078
# Epoch 8/50
# 20/20 - 0s - 7ms/step - loss: 2.7509e-04 - val_loss: 0.0078
# Epoch 9/50
# 20/20 - 0s - 7ms/step - loss: 2.5952e-04 - val_loss: 0.0071
# Epoch 10/50
# 20/20 - 0s - 7ms/step - loss: 2.4654e-04 - val_loss: 0.0063
# Epoch 11/50
# 20/20 - 0s - 7ms/step - loss: 2.8812e-04 - val_loss: 0.0060
# Epoch 12/50
# 20/20 - 0s - 7ms/step - loss: 2.9908e-04 - val_loss: 0.0092
# Epoch 13/50
# 20/20 - 0s - 8ms/step - loss: 4.4944e-04 - val_loss: 0.0135
# Epoch 14/50
# 20/20 - 0s - 7ms/step - loss: 4.4364e-04 - val_loss: 0.0066
# Epoch 15/50
# 20/20 - 0s - 7ms/step - loss: 2.8225e-04 - val_loss: 0.0061
# Epoch 16/50
# 20/20 - 0s - 7ms/step - loss: 2.7724e-04 - val_loss: 0.0081
# Epoch 17/50
# 20/20 - 0s - 7ms/step - loss: 2.4708e-04 - val_loss: 0.0070
# Epoch 18/50
# 20/20 - 0s - 7ms/step - loss: 2.0484e-04 - val_loss: 0.0060
# Epoch 19/50
# 20/20 - 0s - 7ms/step - loss: 1.9695e-04 - val_loss: 0.0066
# Epoch 20/50
# 20/20 - 0s - 7ms/step - loss: 1.9000e-04 - val_loss: 0.0068
# Epoch 21/50
# 20/20 - 0s - 7ms/step - loss: 1.9314e-04 - val_loss: 0.0062
# Epoch 22/50
# 20/20 - 0s - 7ms/step - loss: 1.8558e-04 - val_loss: 0.0063
# Epoch 23/50
# 20/20 - 0s - 7ms/step - loss: 1.8890e-04 - val_loss: 0.0072
# Epoch 24/50
# 20/20 - 0s - 7ms/step - loss: 1.9638e-04 - val_loss: 0.0067
# Epoch 25/50
# 20/20 - 0s - 8ms/step - loss: 1.9679e-04 - val_loss: 0.0060
# Epoch 26/50
# 20/20 - 0s - 9ms/step - loss: 1.9566e-04 - val_loss: 0.0067
# Epoch 27/50
# 20/20 - 0s - 11ms/step - loss: 2.1057e-04 - val_loss: 0.0087
# Epoch 28/50
# 20/20 - 0s - 8ms/step - loss: 2.2504e-04 - val_loss: 0.0066
# Epoch 29/50
# 20/20 - 0s - 10ms/step - loss: 2.1304e-04 - val_loss: 0.0058
# Epoch 30/50
# 20/20 - 0s - 9ms/step - loss: 2.3331e-04 - val_loss: 0.0079
# Epoch 31/50
# 20/20 - 0s - 9ms/step - loss: 2.1318e-04 - val_loss: 0.0080
# Epoch 32/50
# 20/20 - 0s - 19ms/step - loss: 2.1872e-04 - val_loss: 0.0060
# Epoch 33/50
# 20/20 - 0s - 19ms/step - loss: 2.0760e-04 - val_loss: 0.0070
# Epoch 34/50
# 20/20 - 0s - 7ms/step - loss: 1.9965e-04 - val_loss: 0.0085
# Epoch 35/50
# 20/20 - 0s - 7ms/step - loss: 2.1606e-04 - val_loss: 0.0062
# Epoch 36/50
# 20/20 - 0s - 7ms/step - loss: 1.9031e-04 - val_loss: 0.0068
# Epoch 37/50
# 20/20 - 0s - 7ms/step - loss: 1.9251e-04 - val_loss: 0.0083
# Epoch 38/50
# 20/20 - 0s - 7ms/step - loss: 2.0262e-04 - val_loss: 0.0064
# Epoch 39/50
# 20/20 - 0s - 8ms/step - loss: 1.7916e-04 - val_loss: 0.0066
# Epoch 40/50
# 20/20 - 0s - 7ms/step - loss: 1.8858e-04 - val_loss: 0.0083
# Epoch 41/50
# 20/20 - 0s - 7ms/step - loss: 1.9266e-04 - val_loss: 0.0068
# Epoch 42/50
# 20/20 - 0s - 7ms/step - loss: 1.7901e-04 - val_loss: 0.0063
# Epoch 43/50
# 20/20 - 0s - 8ms/step - loss: 1.9397e-04 - val_loss: 0.0086
# Epoch 44/50
# 20/20 - 0s - 7ms/step - loss: 1.9127e-04 - val_loss: 0.0074
# Epoch 45/50
# 20/20 - 0s - 7ms/step - loss: 1.8876e-04 - val_loss: 0.0062
# Epoch 46/50
# 20/20 - 0s - 7ms/step - loss: 1.9891e-04 - val_loss: 0.0084
# Epoch 47/50
# 20/20 - 0s - 7ms/step - loss: 1.8519e-04 - val_loss: 0.0078
# Epoch 48/50
# 20/20 - 0s - 7ms/step - loss: 1.9594e-04 - val_loss: 0.0062
# Epoch 49/50
# 20/20 - 0s - 7ms/step - loss: 1.9861e-04 - val_loss: 0.0084
# Epoch 50/50
# 20/20 - 0s - 7ms/step - loss: 1.8351e-04 - val_loss: 0.0081
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# <class 'numpy.ndarray'>
# [[0.07438852]
#  [0.06628061]
#  [0.07835807]
#  [0.07162497]
#  [0.07826804]
#  [0.0853823 ]
#  [0.06863854]
#  [0.08319075]
#  [0.07632961]
#  [0.08963058]
#  [0.0929208 ]
#  [0.0801864 ]
#  [0.07430061]
#  [0.06648099]
#  [0.06114469]
#  [0.05762478]
#  [0.06001386]
#  [0.05996145]
#  [0.06250194]
#  [0.06071281]
#  [0.05519827]
#  [0.05450149]
#  [0.05946525]
#  [0.06646188]
#  [0.0710463 ]
#  [0.0792358 ]
#  [0.08137285]
#  [0.08385456]
#  [0.0859778 ]
#  [0.08794015]
#  [0.0980944 ]
#  [0.10062539]
#  [0.0961101 ]
#  [0.0968621 ]
#  [0.09364387]
#  [0.10154835]
#  [0.09929757]
#  [0.10993607]
#  [0.10025672]
#  [0.105667  ]
#  [0.09916706]
#  [0.09285989]
#  [0.08715042]
#  [0.08801769]
#  [0.09237029]
#  [0.09124532]
#  [0.11847213]
#  [0.111353  ]
#  [0.11676228]
#  [0.11022668]
#  [0.10327916]
#  [0.10976648]
#  [0.11489947]
#  [0.11624237]
#  [0.11745746]
#  [0.10481728]
#  [0.10504444]
#  [0.10035118]
#  [0.10996131]
#  [0.11331518]
#  [0.12095534]
#  [0.1119191 ]
#  [0.13653225]
#  [0.12497231]
#  [0.13380012]
#  [0.15333737]
#  [0.203108  ]
#  [0.16067226]
#  [0.13777377]
#  [0.13294294]
#  [0.11976684]
#  [0.10749974]
#  [0.10119926]
#  [0.10169568]
#  [0.10648713]
#  [0.10371462]
#  [0.09969213]
#  [0.09804701]
#  [0.10089294]
#  [0.11128496]
#  [0.11074983]
#  [0.11412571]
#  [0.10969541]
#  [0.11282601]
#  [0.16010883]
#  [0.15230359]
#  [0.21278201]
#  [0.26412603]
#  [0.26130405]
#  [0.17942505]
#  [0.10647251]
#  [0.08576494]
#  [0.11428503]
#  [0.13305284]
#  [0.13358073]
#  [0.15151052]
#  [0.12732106]
#  [0.13485259]
#  [0.10448057]
#  [0.12079522]
#  [0.11228744]
#  [0.12199694]
#  [0.11291292]
#  [0.10510031]
#  [0.098111  ]
#  [0.08724756]
#  [0.0770385 ]
#  [0.08015653]
#  [0.07616084]
#  [0.08673855]
#  [0.09479953]
#  [0.07095389]
#  [0.05782425]
#  [0.03897452]
#  [0.04425164]
#  [0.06125902]
#  [0.0647992 ]
#  [0.06887867]
#  [0.0710088 ]
#  [0.07508791]
#  [0.07466687]
#  [0.07718288]
#  [0.07396429]
#  [0.07134426]
#  [0.07086185]
#  [0.06298442]
#  [0.062953  ]
#  [0.05717667]
#  [0.07063107]
#  [0.07382594]
#  [0.06967091]
#  [0.06242625]
#  [0.05916651]
#  [0.06095291]
#  [0.05926716]
#  [0.04523811]
#  [0.01208184]
#  [0.01791827]
#  [0.04859217]
#  [0.05673579]
#  [0.05462992]
#  [0.05708729]
#  [0.05757754]
#  [0.06866054]
#  [0.07073569]
#  [0.06864712]
#  [0.07444738]
#  [0.06401744]
#  [0.0593054 ]
#  [0.05993716]
#  [0.06202721]
#  [0.06515326]
#  [0.06695991]
#  [0.06588554]
#  [0.06021193]
#  [0.05765662]
#  [0.05732772]
#  [0.06069704]
#  [0.05954261]
#  [0.06068506]
#  [0.06045471]
#  [0.06043702]
#  [0.06346124]
#  [0.06955395]
#  [0.0626275 ]
#  [0.06025255]
#  [0.06543459]
#  [0.06565731]
#  [0.06080285]
#  [0.06839053]
#  [0.07027343]
#  [0.07552401]
#  [0.08252922]
#  [0.08033539]
#  [0.08891169]
#  [0.08674518]
#  [0.08511545]
#  [0.09362077]
#  [0.09222118]
#  [0.09205023]
#  [0.09547354]
#  [0.098216  ]
#  [0.08978517]
#  [0.08966429]
#  [0.09794577]
#  [0.09905981]
#  [0.10611214]
#  [0.1056389 ]
#  [0.10467996]
#  [0.09677105]
#  [0.0940644 ]
#  [0.10425902]
#  [0.12057944]
#  [0.13279925]
#  [0.12568153]
#  [0.1273487 ]
#  [0.11518718]
#  [0.12675221]
#  [0.14172755]
#  [0.16062716]
#  [0.16359268]
#  [0.17223509]
#  [0.17357284]
#  [0.1404316 ]
#  [0.13299875]
#  [0.15424806]
#  [0.1667836 ]
#  [0.20518619]
#  [0.18827707]
#  [0.163686  ]
#  [0.12757282]
#  [0.14158475]
#  [0.13850959]
#  [0.1278112 ]
#  [0.12798065]
#  [0.14231592]
#  [0.13566303]
#  [0.16429916]
#  [0.14103521]
#  [0.14409275]
#  [0.13045914]
#  [0.12882976]
#  [0.12265718]
#  [0.1310205 ]
#  [0.12301805]
#  [0.11676487]
#  [0.11635496]
#  [0.11427846]
#  [0.12120854]
#  [0.12772971]
#  [0.1379104 ]
#  [0.12832743]
#  [0.12269194]
#  [0.14135914]
#  [0.17260161]
#  [0.23998119]
#  [0.22140355]
#  [0.17856976]
#  [0.15230936]
#  [0.1444765 ]
#  [0.15360987]
#  [0.14451244]
#  [0.15404464]
#  [0.17209825]
#  [0.17120346]
#  [0.15768461]
#  [0.15003431]
#  [0.14725631]
#  [0.15879233]
#  [0.16249563]
#  [0.17963088]
#  [0.17157261]
#  [0.15425415]
#  [0.14128684]
#  [0.16356078]
#  [0.18962508]
#  [0.23571561]
#  [0.27275163]
#  [0.2666089 ]
#  [0.2640112 ]
#  [0.2182569 ]
#  [0.22970258]
#  [0.22041412]
#  [0.23344333]
#  [0.20826256]
#  [0.22897871]
#  [0.22109927]
#  [0.20226704]
#  [0.20319109]
#  [0.21322006]
#  [0.21867415]
#  [0.23070623]
#  [0.1993802 ]
#  [0.21372777]
#  [0.21629447]
#  [0.23840643]
#  [0.22396071]
#  [0.23036839]
#  [0.22024173]
#  [0.18336098]
#  [0.17911159]
#  [0.18604396]
#  [0.21948926]
#  [0.24742897]
#  [0.24284711]
#  [0.23811652]
#  [0.2366976 ]
#  [0.23617649]
#  [0.25050545]
#  [0.25029358]
#  [0.2431168 ]
#  [0.26432946]
#  [0.24967323]
#  [0.22296111]
#  [0.20556872]
#  [0.21683247]
#  [0.31356508]
#  [0.26057354]
#  [0.23067828]
#  [0.19973505]
#  [0.19711745]
#  [0.18706845]
#  [0.1644463 ]
#  [0.1738385 ]
#  [0.1610507 ]
#  [0.17343666]
#  [0.16250053]
#  [0.1293645 ]
#  [0.11908281]
#  [0.1022173 ]
#  [0.09746706]
#  [0.09367458]]
# rmse = 0.0900936920676096
# mae = 0.05231864211463334
# mape = 0.27069591173917923
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.11055668290208993  mae = 0.0787651697935592 mape = 0.5152234023161364
#
# coinbase
# rmse = 0.15676515981270583  mae = 0.1302915850006521 mape = 0.8694953218740641
#
# huobi
# rmse = 0.07288621602264281  mae = 0.02540074173293107 mape = 0.34285848164275673
#
# kraken
# rmse = 0.16714118293107924  mae = 0.09931252662788892 mape = 0.5258761375786698
#
# kucoin
# rmse = 0.0900936920676096  mae = 0.05231864211463334 mape = 0.27069591173917923

# %%
1
